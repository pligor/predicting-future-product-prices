# %%
# -*- coding: UTF-8 -*-
#%load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# %%
from __future__ import division
import tensorflow as tf
from os import path
import numpy as np
import pandas as pd
import csv
from sklearn.model_selection import StratifiedShuffleSplit
from time import time
from matplotlib import pyplot as plt
import seaborn as sns
from mylibs.jupyter_notebook_helper import show_graph
from tensorflow.contrib import rnn
from tensorflow.contrib import learn
import shutil
from tensorflow.contrib.learn.python.learn import learn_runner
from IPython.display import Image
from IPython.core.display import HTML
from mylibs.tf_helper import getDefaultGPUconfig
from sklearn.metrics import r2_score
from mylibs.py_helper import factors
from fastdtw import fastdtw
from scipy.spatial.distance import euclidean
from statsmodels.tsa.stattools import coint
from data_providers.price_history_dataset_generator import PriceHistoryDatasetGenerator
from sklearn.linear_model import LinearRegression
from scipy.signal import detrend
from common import get_or_run_nn
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import coint
from models.my_baseline import MyBaseline
# Out:
# /home/studenthp/anaconda2/envs/dis/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
dtype = tf.float32
seed = 16011984
random_state = np.random.RandomState(seed=seed)
config = getDefaultGPUconfig()
# %matplotlib inline

# %%
ph_data_path = '../data/price_history'

# %%
npz_train_reduced = ph_data_path + '/price_history_mobattrs_dp_60to30_57994_trimmed_small_train.npz'
npz_train = ph_data_path + '/price_history_mobattrs_dp_60to30_57994_trimmed_train.npz'
npz_test = ph_data_path + '/price_history_mobattrs_dp_60to30_57994_trimmed_test.npz'
assert path.isfile(npz_train_reduced)
assert path.isfile(npz_train)
assert path.isfile(npz_test)

# %%
#Our batch size is 64 that is why we want train and test size that will be divided exactly by 64
batch_size = 100
train_full_size = len(np.load(npz_train)['inputs'])
train_size = len(np.load(npz_train_reduced)['inputs'])
test_size = len(np.load(npz_test)['inputs'])
assert train_size % batch_size == 0 and test_size % batch_size == 0

train_full_size, train_size, test_size
# Out:
# (46000, 7000, 11500)

# %% [markdown]
# # Baseline is static, a straight line for each input - Test

# %%
bltest = MyBaseline(npz_path=npz_test)

# %%
bltest.getMSE()
# Out:
# 0.0073908535067763598

# %%
bltest.renderMSEs()
plt.show()

# %%
bltest.getHuberLoss()
# Out:
# 0.0056931375037922458

# %%
bltest.renderHuberLosses()
plt.show()

# %%
bltest.get_dtw()
# Out:
# 1.1529655138886203

# %%
bltest.renderRandomTargetVsPrediction()
plt.show()

# %% [markdown]
# # Baseline is static, a straight line for each input - Train (reduced)

# %%
cur_baseline = MyBaseline(npz_path=npz_train_reduced)

# %%
cur_baseline.getMSE()
# Out:
# 0.0070452776719187567

# %%
cur_baseline.renderMSEs()
plt.show()

# %%
cur_baseline.getHuberLoss()
# Out:
# 0.0060701828701207952

# %%
cur_baseline.renderHuberLosses()
plt.show()

# %%
cur_baseline.get_dtw()
# Out:
# 1.1232360721201493

# %%
cur_baseline.renderRandomTargetVsPrediction()
plt.show()

# %% [markdown]
# # Baseline is static, a straight line for each input - Train Full

# %%
cur_baseline = MyBaseline(npz_path=npz_train)

# %%
cur_baseline.getMSE()
# Out:
# 0.0073279714653608869

# %%
cur_baseline.renderMSEs()
plt.show()

# %%
cur_baseline.getHuberLoss()
# Out:
# 0.0057078143316891495

# %%
cur_baseline.renderHuberLosses()
plt.show()

# %%
cur_baseline.get_dtw()
# Out:
# 1.1443938473450168

# %%
cur_baseline.renderRandomTargetVsPrediction()
plt.show()
