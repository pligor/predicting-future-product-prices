# %%
# -*- coding: UTF-8 -*-
#%load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# %%
from __future__ import division
import tensorflow as tf
from os import path, remove
import numpy as np
import pandas as pd
import csv
from sklearn.model_selection import StratifiedShuffleSplit
from time import time
from matplotlib import pyplot as plt
import seaborn as sns
from mylibs.jupyter_notebook_helper import show_graph, renderStatsList, renderStatsCollection, \
    renderStatsListWithLabels, renderStatsCollectionOfCrossValids, plot_res_gp, my_plot_convergence
from tensorflow.contrib import rnn
from tensorflow.contrib import learn
import shutil
from tensorflow.contrib.learn.python.learn import learn_runner
from mylibs.tf_helper import getDefaultGPUconfig
from sklearn.metrics import r2_score
from mylibs.py_helper import factors
from fastdtw import fastdtw
from collections import OrderedDict
from scipy.spatial.distance import euclidean
from statsmodels.tsa.stattools import coint
from common_33 import get_or_run_nn
from skopt.space.space import Integer, Real
from skopt import gp_minimize
from skopt.plots import plot_convergence
import pickle
import inspect
import dill
import sys

from models.model_35_price_history_autoencoder import PriceHistoryAutoencoder
from data_providers.data_provider_33_price_history_autoencoder import PriceHistoryAutoEncDataProvider
#from gp_opt.price_history_27_gp_opt import PriceHistoryGpOpt
# Out:
# /home/studenthp/anaconda2/envs/dis/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
dtype = tf.float32
seed = 16011984
random_state = np.random.RandomState(seed=seed)
config = getDefaultGPUconfig()
n_jobs = 1
# %matplotlib inline

# %% [markdown]
# ### Step 0 - hyperparams

# %%
factors(689)
# Out:
# [1, 53, 13, 689]

# %%
max_seq_len = 682

# %%
#full_train_size = 55820
#train_size = 55800
#small_train_size = 6000 #just because of performance reasons, no statistics behind this decision
#test_size = 6200

# %%
data_path = '../../../../Dropbox/data'

# %%
phae_path = data_path + '/price_hist_autoencoder'

# %%
csv_in = '../price_history_03_seq_start_suddens_trimmed.csv'
assert path.isfile(csv_in)

# %%
npz_unprocessed = phae_path + '/price_history_full_seqs.npz'
assert path.isfile(npz_unprocessed)

# %%
npz_dates = phae_path + '/price_history_full_seqs_dates.npz'
assert path.isfile(npz_dates)

# %%
npz_train = phae_path + '/price_history_seqs_dates_normed_train.npz'
assert path.isfile(npz_train)

# %%
npz_test = phae_path + '/price_history_seqs_dates_normed_test.npz'
assert path.isfile(npz_test)

# %%
npz_path = npz_train[:-len('_train.npz')]

# %%
for key, val in np.load(npz_train).iteritems():
    print key, ",", val.shape
# Out:
# inputs , (689, 682, 7)
# sku_ids , (689,)
# sequence_masks , (689, 682)
# extra_inputs , (689, 682, 6)
# sequence_lengths , (689,)

# %% [markdown]
# ### Step 1 - collect data

# %%
dp = PriceHistoryAutoEncDataProvider(npz_path=npz_path, batch_size=53, with_EOS=False)
for data in dp.datalist:
    print data.shape
# Out:
# (689, 682, 7)
# (689, 682, 6)
# (689,)
# (689, 682)

# %%
# for item in dp.next():
#     print item.shape

# %% [markdown]
# ### Step 2 - Build model

# %%
# model = PriceHistoryAutoencoder(rng=random_state, dtype=dtype, config=config)
# graph = model.getGraph(batch_size=53,
#                        enc_num_units = 10,
#                        dec_num_units = 10,
#                        ts_len=max_seq_len)

# %% [markdown]
# targets
# Tensor("data/strided_slice:0", shape=(53, 682), dtype=float32)
#
# Tensor("encoder_rnn_layer/rnn/while/Exit_2:0", shape=(?, 10), dtype=float32)
#
# Tensor("encoder_state_out_process/Elu:0", shape=(?, 2), dtype=float32)
#
# Tensor("decoder_state_in_process/Elu:0", shape=(?, 10), dtype=float32)
#
# Tensor("decoder_rnn_layer/rnn/transpose:0", shape=(53, 682, 10), dtype=float32)
#
# Tensor("decoder_outs/Reshape:0", shape=(36146, 10), dtype=float32)
#
# Tensor("readout_affine/Identity:0", shape=(36146, 1), dtype=float32)
# Tensor("readout_affine/Reshape:0", shape=(53, 682), dtype=float32)
#
# Tensor("error/mul_1:0", shape=(53, 682), dtype=float32)
#
# Tensor("error/Mean:0", shape=(), dtype=float32)
# Tensor("error/Mean:0", shape=(), dtype=float32)
#
# Tensor("error_diff/mul_1:0", shape=(53, 681), dtype=float32)
#
# Tensor("error_diff/Mean:0", shape=(), dtype=float32)
# Tensor("error_diff/Mean:0", shape=(), dtype=float32)

# %%
#show_graph(graph)

# %% [markdown]
# ## Quick test run

# %%
def experiment():
    return model.run(npz_path=npz_path,
                     epochs=2,
                     batch_size = 53,
                     enc_num_units = 400,
                     dec_num_units = 400,
                     ts_len=max_seq_len,
                     learning_rate = 1e-4,
                     preds_gather_enabled = False,
                    )
dyn_stats_dic = experiment()

# %%
dyn_stats_dic['dyn_stats'].plotStats()
plt.show()
dyn_stats_dic['dyn_stats_diff'].plotStats()
plt.show()

# %% [markdown]
# ### Step 3 training the network

# %%
model = PriceHistoryAutoencoder(rng=random_state, dtype=dtype, config=config)

# %%
npz_test = npz_path + '_test.npz'
assert path.isfile(npz_test)
path.abspath(npz_test)
# Out:
# '/home/studenthp/Dropbox/data/price_hist_autoencoder/price_history_seqs_dates_normed_test.npz'

# %%
def experiment():
    return model.run(npz_path=npz_path,
                     epochs=200,
                     batch_size = 53,
                     enc_num_units = 450,
                     dec_num_units = 450,
                     ts_len=max_seq_len,
                     learning_rate = 1e-4,
                     preds_gather_enabled = True,
                    )

# %%
#%%time
# dyn_stats_dic, preds_dict, targets, twods = experiment()
dyn_stats, preds_dict, targets, twods = get_or_run_nn(experiment, filename='035_autoencoder_000',
                                                      nn_runs_folder = data_path + "/nn_runs")
# Out:
# epochs: 200
# dec_num_units: 450
# learning_rate: 0.0001
# enc_num_units: 450
# End Epoch 01 (116.443 secs): err(train) = 0.006671, err_diff(train) = 0.000200
# End Epoch 02 (116.180 secs): err(train) = 0.004985, err_diff(train) = 0.000163
# End Epoch 03 (116.186 secs): err(train) = 0.004808, err_diff(train) = 0.000158
# End Epoch 04 (116.055 secs): err(train) = 0.004713, err_diff(train) = 0.000157
# End Epoch 05 (115.975 secs): err(train) = 0.004651, err_diff(train) = 0.000156
# End Epoch 06 (116.041 secs): err(train) = 0.004505, err_diff(train) = 0.000156
# End Epoch 07 (116.066 secs): err(train) = 0.004225, err_diff(train) = 0.000156
# End Epoch 08 (116.121 secs): err(train) = 0.002620, err_diff(train) = 0.000156
# End Epoch 09 (116.154 secs): err(train) = 0.001989, err_diff(train) = 0.000155
# End Epoch 10 (116.185 secs): err(train) = 0.001947, err_diff(train) = 0.000155
# End Epoch 11 (116.145 secs): err(train) = 0.002210, err_diff(train) = 0.000155
# End Epoch 12 (116.214 secs): err(train) = 0.002159, err_diff(train) = 0.000155
# End Epoch 13 (116.202 secs): err(train) = 0.001793, err_diff(train) = 0.000155
# End Epoch 14 (116.238 secs): err(train) = 0.001843, err_diff(train) = 0.000155
# End Epoch 15 (116.092 secs): err(train) = 0.001880, err_diff(train) = 0.000155
# End Epoch 16 (116.235 secs): err(train) = 0.001689, err_diff(train) = 0.000155
# End Epoch 17 (116.184 secs): err(train) = 0.001902, err_diff(train) = 0.000155
# End Epoch 18 (116.211 secs): err(train) = 0.001741, err_diff(train) = 0.000155
# End Epoch 19 (116.168 secs): err(train) = 0.001827, err_diff(train) = 0.000155
# End Epoch 20 (115.967 secs): err(train) = 0.002125, err_diff(train) = 0.000155
# End Epoch 21 (116.054 secs): err(train) = 0.001800, err_diff(train) = 0.000155
# End Epoch 22 (116.132 secs): err(train) = 0.001751, err_diff(train) = 0.000155
# End Epoch 23 (116.068 secs): err(train) = 0.001822, err_diff(train) = 0.000155
# End Epoch 24 (116.213 secs): err(train) = 0.001731, err_diff(train) = 0.000155
# End Epoch 25 (116.193 secs): err(train) = 0.001928, err_diff(train) = 0.000155
# End Epoch 26 (116.134 secs): err(train) = 0.001851, err_diff(train) = 0.000155
# End Epoch 27 (116.101 secs): err(train) = 0.001635, err_diff(train) = 0.000155
# End Epoch 28 (116.159 secs): err(train) = 0.001689, err_diff(train) = 0.000155
# End Epoch 29 (116.119 secs): err(train) = 0.001480, err_diff(train) = 0.000155
# End Epoch 30 (116.090 secs): err(train) = 0.001659, err_diff(train) = 0.000155
# End Epoch 31 (116.048 secs): err(train) = 0.001602, err_diff(train) = 0.000155
# End Epoch 32 (116.092 secs): err(train) = 0.001596, err_diff(train) = 0.000155
# End Epoch 33 (116.099 secs): err(train) = 0.001434, err_diff(train) = 0.000155
# End Epoch 34 (116.116 secs): err(train) = 0.001552, err_diff(train) = 0.000155
# End Epoch 35 (116.037 secs): err(train) = 0.001695, err_diff(train) = 0.000155
# End Epoch 36 (116.085 secs): err(train) = 0.001506, err_diff(train) = 0.000155
# End Epoch 37 (116.057 secs): err(train) = 0.001635, err_diff(train) = 0.000155
# End Epoch 38 (116.066 secs): err(train) = 0.001564, err_diff(train) = 0.000155
# End Epoch 39 (116.129 secs): err(train) = 0.001508, err_diff(train) = 0.000155
# End Epoch 40 (116.029 secs): err(train) = 0.001838, err_diff(train) = 0.000155
# End Epoch 41 (116.138 secs): err(train) = 0.001794, err_diff(train) = 0.000155
# End Epoch 42 (116.187 secs): err(train) = 0.001770, err_diff(train) = 0.000155
# End Epoch 43 (116.194 secs): err(train) = 0.001818, err_diff(train) = 0.000156
# End Epoch 44 (116.094 secs): err(train) = 0.001591, err_diff(train) = 0.000156
# End Epoch 45 (115.816 secs): err(train) = 0.001463, err_diff(train) = 0.000155
# End Epoch 46 (115.848 secs): err(train) = 0.001503, err_diff(train) = 0.000155
# End Epoch 47 (115.903 secs): err(train) = 0.001376, err_diff(train) = 0.000155
# End Epoch 48 (116.017 secs): err(train) = 0.001460, err_diff(train) = 0.000155
# End Epoch 49 (116.150 secs): err(train) = 0.001533, err_diff(train) = 0.000155
# End Epoch 50 (116.026 secs): err(train) = 0.001447, err_diff(train) = 0.000155
# End Epoch 51 (116.037 secs): err(train) = 0.001612, err_diff(train) = 0.000155
# End Epoch 52 (116.079 secs): err(train) = 0.001948, err_diff(train) = 0.000155
# End Epoch 53 (116.089 secs): err(train) = 0.001721, err_diff(train) = 0.000155
# End Epoch 54 (116.129 secs): err(train) = 0.001868, err_diff(train) = 0.000155
# End Epoch 55 (116.213 secs): err(train) = 0.001549, err_diff(train) = 0.000155
# End Epoch 56 (116.190 secs): err(train) = 0.001418, err_diff(train) = 0.000155
# End Epoch 57 (116.133 secs): err(train) = 0.001632, err_diff(train) = 0.000155
# End Epoch 58 (116.173 secs): err(train) = 0.001604, err_diff(train) = 0.000155
# End Epoch 59 (116.136 secs): err(train) = 0.001377, err_diff(train) = 0.000155
# End Epoch 60 (116.076 secs): err(train) = 0.001409, err_diff(train) = 0.000155
# End Epoch 61 (116.092 secs): err(train) = 0.001449, err_diff(train) = 0.000155
# End Epoch 62 (116.173 secs): err(train) = 0.001397, err_diff(train) = 0.000155
# End Epoch 63 (116.224 secs): err(train) = 0.001361, err_diff(train) = 0.000155
# End Epoch 64 (116.205 secs): err(train) = 0.001599, err_diff(train) = 0.000155
# End Epoch 65 (116.181 secs): err(train) = 0.001378, err_diff(train) = 0.000155
# End Epoch 66 (116.102 secs): err(train) = 0.001424, err_diff(train) = 0.000155
# End Epoch 67 (116.157 secs): err(train) = 0.001428, err_diff(train) = 0.000155
# End Epoch 68 (116.078 secs): err(train) = 0.001324, err_diff(train) = 0.000155
# End Epoch 69 (116.018 secs): err(train) = 0.001416, err_diff(train) = 0.000155
# End Epoch 70 (116.028 secs): err(train) = 0.001512, err_diff(train) = 0.000154
# End Epoch 71 (116.130 secs): err(train) = 0.001618, err_diff(train) = 0.000155
# End Epoch 72 (116.158 secs): err(train) = 0.001386, err_diff(train) = 0.000155
# End Epoch 73 (116.139 secs): err(train) = 0.001599, err_diff(train) = 0.000155
# End Epoch 74 (116.246 secs): err(train) = 0.001707, err_diff(train) = 0.000155
# End Epoch 75 (116.209 secs): err(train) = 0.001593, err_diff(train) = 0.000155
# End Epoch 76 (116.150 secs): err(train) = 0.001451, err_diff(train) = 0.000155
# End Epoch 77 (116.195 secs): err(train) = 0.001256, err_diff(train) = 0.000155
# End Epoch 78 (116.196 secs): err(train) = 0.001206, err_diff(train) = 0.000155
# End Epoch 79 (116.302 secs): err(train) = 0.001166, err_diff(train) = 0.000155
# End Epoch 80 (116.270 secs): err(train) = 0.001289, err_diff(train) = 0.000154
# End Epoch 81 (116.193 secs): err(train) = 0.001306, err_diff(train) = 0.000155
# End Epoch 82 (116.150 secs): err(train) = 0.001235, err_diff(train) = 0.000155
# End Epoch 83 (116.232 secs): err(train) = 0.001174, err_diff(train) = 0.000155
# End Epoch 84 (116.246 secs): err(train) = 0.001489, err_diff(train) = 0.000155
# End Epoch 85 (116.163 secs): err(train) = 0.001284, err_diff(train) = 0.000155
# End Epoch 86 (116.181 secs): err(train) = 0.001267, err_diff(train) = 0.000154
# End Epoch 87 (116.256 secs): err(train) = 0.001275, err_diff(train) = 0.000155
# End Epoch 88 (116.096 secs): err(train) = 0.001343, err_diff(train) = 0.000155
# End Epoch 89 (116.315 secs): err(train) = 0.001209, err_diff(train) = 0.000155
# End Epoch 90 (116.215 secs): err(train) = 0.001327, err_diff(train) = 0.000155
# End Epoch 91 (116.184 secs): err(train) = 0.001272, err_diff(train) = 0.000155
# End Epoch 92 (116.176 secs): err(train) = 0.001270, err_diff(train) = 0.000155
# End Epoch 93 (116.150 secs): err(train) = 0.001199, err_diff(train) = 0.000155
# End Epoch 94 (116.177 secs): err(train) = 0.001293, err_diff(train) = 0.000154
# End Epoch 95 (116.108 secs): err(train) = 0.001290, err_diff(train) = 0.000155
# End Epoch 96 (116.137 secs): err(train) = 0.001258, err_diff(train) = 0.000155
# End Epoch 97 (116.217 secs): err(train) = 0.001243, err_diff(train) = 0.000155
# End Epoch 98 (116.166 secs): err(train) = 0.001300, err_diff(train) = 0.000155
# End Epoch 99 (116.260 secs): err(train) = 0.001141, err_diff(train) = 0.000155
# End Epoch 100 (116.230 secs): err(train) = 0.001285, err_diff(train) = 0.000154
# End Epoch 101 (116.242 secs): err(train) = 0.001297, err_diff(train) = 0.000155
# End Epoch 102 (116.079 secs): err(train) = 0.001509, err_diff(train) = 0.000155
# End Epoch 103 (116.078 secs): err(train) = 0.001763, err_diff(train) = 0.000155
# End Epoch 104 (116.092 secs): err(train) = 0.001319, err_diff(train) = 0.000155
# End Epoch 105 (116.191 secs): err(train) = 0.001344, err_diff(train) = 0.000154
# End Epoch 106 (116.081 secs): err(train) = 0.001289, err_diff(train) = 0.000155
# End Epoch 107 (116.205 secs): err(train) = 0.001401, err_diff(train) = 0.000154
# End Epoch 108 (116.030 secs): err(train) = 0.001555, err_diff(train) = 0.000154
# End Epoch 109 (116.143 secs): err(train) = 0.001684, err_diff(train) = 0.000155
# End Epoch 110 (116.069 secs): err(train) = 0.001416, err_diff(train) = 0.000155
# End Epoch 111 (116.181 secs): err(train) = 0.001338, err_diff(train) = 0.000155
# End Epoch 112 (116.139 secs): err(train) = 0.001266, err_diff(train) = 0.000155
# End Epoch 113 (115.989 secs): err(train) = 0.001259, err_diff(train) = 0.000154
# End Epoch 114 (116.090 secs): err(train) = 0.001252, err_diff(train) = 0.000155
# End Epoch 115 (116.154 secs): err(train) = 0.001221, err_diff(train) = 0.000155
# End Epoch 116 (116.166 secs): err(train) = 0.001172, err_diff(train) = 0.000155
# End Epoch 117 (116.111 secs): err(train) = 0.001050, err_diff(train) = 0.000154
# End Epoch 118 (116.217 secs): err(train) = 0.001127, err_diff(train) = 0.000154
# End Epoch 119 (116.197 secs): err(train) = 0.001069, err_diff(train) = 0.000154
# End Epoch 120 (116.260 secs): err(train) = 0.001069, err_diff(train) = 0.000154
# End Epoch 121 (116.125 secs): err(train) = 0.001199, err_diff(train) = 0.000154
# End Epoch 122 (116.179 secs): err(train) = 0.001502, err_diff(train) = 0.000155
# End Epoch 123 (116.138 secs): err(train) = 0.001641, err_diff(train) = 0.000155
# End Epoch 124 (116.170 secs): err(train) = 0.001345, err_diff(train) = 0.000155
# End Epoch 125 (116.174 secs): err(train) = 0.001265, err_diff(train) = 0.000155
# End Epoch 126 (116.160 secs): err(train) = 0.001237, err_diff(train) = 0.000155
# End Epoch 127 (116.158 secs): err(train) = 0.001175, err_diff(train) = 0.000155
# End Epoch 128 (116.047 secs): err(train) = 0.001116, err_diff(train) = 0.000154
# End Epoch 129 (116.174 secs): err(train) = 0.001140, err_diff(train) = 0.000154
# End Epoch 130 (116.221 secs): err(train) = 0.001197, err_diff(train) = 0.000155
# End Epoch 131 (116.059 secs): err(train) = 0.001190, err_diff(train) = 0.000154
# End Epoch 132 (116.058 secs): err(train) = 0.001294, err_diff(train) = 0.000154
# End Epoch 133 (116.072 secs): err(train) = 0.001161, err_diff(train) = 0.000154
# End Epoch 134 (116.181 secs): err(train) = 0.001169, err_diff(train) = 0.000154
# End Epoch 135 (116.259 secs): err(train) = 0.001196, err_diff(train) = 0.000154
# End Epoch 136 (116.236 secs): err(train) = 0.001072, err_diff(train) = 0.000154
# End Epoch 137 (116.193 secs): err(train) = 0.001286, err_diff(train) = 0.000154
# End Epoch 138 (116.109 secs): err(train) = 0.001305, err_diff(train) = 0.000154
# End Epoch 139 (116.142 secs): err(train) = 0.001149, err_diff(train) = 0.000154
# End Epoch 140 (116.216 secs): err(train) = 0.001116, err_diff(train) = 0.000155
# End Epoch 141 (116.112 secs): err(train) = 0.000974, err_diff(train) = 0.000154
# End Epoch 142 (116.184 secs): err(train) = 0.000972, err_diff(train) = 0.000154
# End Epoch 143 (116.202 secs): err(train) = 0.000937, err_diff(train) = 0.000154
# End Epoch 144 (116.148 secs): err(train) = 0.001179, err_diff(train) = 0.000154
# End Epoch 145 (116.197 secs): err(train) = 0.001577, err_diff(train) = 0.000154
# End Epoch 146 (116.140 secs): err(train) = 0.001642, err_diff(train) = 0.000154
# End Epoch 147 (116.220 secs): err(train) = 0.001163, err_diff(train) = 0.000154
# End Epoch 148 (116.105 secs): err(train) = 0.001163, err_diff(train) = 0.000154
# End Epoch 149 (116.243 secs): err(train) = 0.000975, err_diff(train) = 0.000154
# End Epoch 150 (116.219 secs): err(train) = 0.001081, err_diff(train) = 0.000154
# End Epoch 151 (116.255 secs): err(train) = 0.001155, err_diff(train) = 0.000154
# End Epoch 152 (116.218 secs): err(train) = 0.001000, err_diff(train) = 0.000155
# End Epoch 153 (116.070 secs): err(train) = 0.001039, err_diff(train) = 0.000155
# End Epoch 154 (116.179 secs): err(train) = 0.000968, err_diff(train) = 0.000154
# End Epoch 155 (116.259 secs): err(train) = 0.000966, err_diff(train) = 0.000154
# End Epoch 156 (116.092 secs): err(train) = 0.001157, err_diff(train) = 0.000154
# End Epoch 157 (116.196 secs): err(train) = 0.000939, err_diff(train) = 0.000154
# End Epoch 158 (116.117 secs): err(train) = 0.000985, err_diff(train) = 0.000154
# End Epoch 159 (116.186 secs): err(train) = 0.001104, err_diff(train) = 0.000154
# End Epoch 160 (116.098 secs): err(train) = 0.001205, err_diff(train) = 0.000154
# End Epoch 161 (116.239 secs): err(train) = 0.001040, err_diff(train) = 0.000154
# End Epoch 162 (116.243 secs): err(train) = 0.001020, err_diff(train) = 0.000154
# End Epoch 163 (116.096 secs): err(train) = 0.001016, err_diff(train) = 0.000154
# End Epoch 164 (116.271 secs): err(train) = 0.000940, err_diff(train) = 0.000154
# End Epoch 165 (116.207 secs): err(train) = 0.001239, err_diff(train) = 0.000154
# End Epoch 166 (116.225 secs): err(train) = 0.000971, err_diff(train) = 0.000154
# End Epoch 167 (116.279 secs): err(train) = 0.001054, err_diff(train) = 0.000154
# End Epoch 168 (116.228 secs): err(train) = 0.000918, err_diff(train) = 0.000154
# End Epoch 169 (116.269 secs): err(train) = 0.000868, err_diff(train) = 0.000154
# End Epoch 170 (116.140 secs): err(train) = 0.000871, err_diff(train) = 0.000154
# End Epoch 171 (116.143 secs): err(train) = 0.000953, err_diff(train) = 0.000154
# End Epoch 172 (116.238 secs): err(train) = 0.001245, err_diff(train) = 0.000154
# End Epoch 173 (116.224 secs): err(train) = 0.001105, err_diff(train) = 0.000154
# End Epoch 174 (116.258 secs): err(train) = 0.000924, err_diff(train) = 0.000154
# End Epoch 175 (116.220 secs): err(train) = 0.000956, err_diff(train) = 0.000154
# End Epoch 176 (116.160 secs): err(train) = 0.000957, err_diff(train) = 0.000154
# End Epoch 177 (116.078 secs): err(train) = 0.000906, err_diff(train) = 0.000154
# End Epoch 178 (116.101 secs): err(train) = 0.000913, err_diff(train) = 0.000154
# End Epoch 179 (116.216 secs): err(train) = 0.000887, err_diff(train) = 0.000154
# End Epoch 180 (115.260 secs): err(train) = 0.001023, err_diff(train) = 0.000154
# End Epoch 181 (114.539 secs): err(train) = 0.000979, err_diff(train) = 0.000154
# End Epoch 182 (114.614 secs): err(train) = 0.000903, err_diff(train) = 0.000154
# End Epoch 183 (114.527 secs): err(train) = 0.000869, err_diff(train) = 0.000154
# End Epoch 184 (114.432 secs): err(train) = 0.000865, err_diff(train) = 0.000154
# End Epoch 185 (114.520 secs): err(train) = 0.000808, err_diff(train) = 0.000154
# End Epoch 186 (114.460 secs): err(train) = 0.000917, err_diff(train) = 0.000154
# End Epoch 187 (114.503 secs): err(train) = 0.000861, err_diff(train) = 0.000154
# End Epoch 188 (114.577 secs): err(train) = 0.001121, err_diff(train) = 0.000154
# End Epoch 189 (114.546 secs): err(train) = 0.001022, err_diff(train) = 0.000154
# End Epoch 190 (114.536 secs): err(train) = 0.000970, err_diff(train) = 0.000154
# End Epoch 191 (114.474 secs): err(train) = 0.000993, err_diff(train) = 0.000154
# End Epoch 192 (114.526 secs): err(train) = 0.000984, err_diff(train) = 0.000154
# End Epoch 193 (114.565 secs): err(train) = 0.000931, err_diff(train) = 0.000154
# End Epoch 194 (114.530 secs): err(train) = 0.001047, err_diff(train) = 0.000154
# End Epoch 195 (114.629 secs): err(train) = 0.000974, err_diff(train) = 0.000154
# End Epoch 196 (114.462 secs): err(train) = 0.000969, err_diff(train) = 0.000154
# End Epoch 197 (114.480 secs): err(train) = 0.001165, err_diff(train) = 0.000154
# End Epoch 198 (114.595 secs): err(train) = 0.000997, err_diff(train) = 0.000154
# End Epoch 199 (114.638 secs): err(train) = 0.001034, err_diff(train) = 0.000154
# End Epoch 200 (114.621 secs): err(train) = 0.000987, err_diff(train) = 0.000154
# total test error: 0.0036020520179
# total test diff error: 0.000156157041112

# %%
dyn_stats['dyn_stats'].plotStats()
plt.show()
dyn_stats['dyn_stats_diff'].plotStats()
plt.show()

# %%
r2_scores = [r2_score(y_true=targets[ind], y_pred=preds_dict[ind])
            for ind in range(len(targets))]

# %%
ind = np.argmin(r2_scores)
ind
# Out:
# 536

# %%
reals = targets[ind]
preds = preds_dict[ind]

# %%
r2_score(y_true=reals, y_pred=preds)
# Out:
# -9857860.8916007578

# %%
#sns.tsplot(data=dp.inputs[ind].flatten())

# %%
fig = plt.figure(figsize=(15,6))
plt.plot(reals, 'b')
plt.plot(preds, 'g')
plt.legend(['reals','preds'])
plt.show()

# %%
# %%time
dtw_scores = [fastdtw(targets[ind], preds_dict[ind])[0]
             for ind in range(len(targets))]
# Out:
# CPU times: user 10.7 s, sys: 68 ms, total: 10.8 s
# Wall time: 10.7 s

# %%
np.mean(dtw_scores)
# Out:
# 14.242576749439843

# %%
coint(preds, reals)
# Out:
# (-0.10771922892460338,
#  0.98305911900708309,
#  array([-3.9490978 , -3.36524107, -3.06461157]))

# %%
cur_ind = np.random.randint(len(targets))
reals = targets[cur_ind]
preds = preds_dict[cur_ind]
fig = plt.figure(figsize=(15,6))
plt.plot(reals, 'b', label='reals')
plt.plot(preds, 'g')
plt.legend(['reals','preds'])
plt.show()

# %% [markdown]
# ### Conclusion
# The autoencoder is not able to represent in a visibly obvious way our price history time series

# %% [markdown]
# # TS in Two Dimensions

# %%
twod_arr = np.array(twods.values())
twod_arr.shape
# Out:
# (689, 2)

# %%
plt.figure(figsize=(16,7))
plt.plot(twod_arr[:, 0], twod_arr[:, 1], 'r.')
plt.title('two dimensional representation of our time series after dimensionality reduction')
plt.xlabel('first dimension')
plt.ylabel('second dimension')
plt.show()
