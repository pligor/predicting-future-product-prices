# %%
# -*- coding: UTF-8 -*-
#%load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# %%
from __future__ import division
import tensorflow as tf
from os import path, remove
import numpy as np
import pandas as pd
import csv
from sklearn.model_selection import StratifiedShuffleSplit
from time import time
from matplotlib import pyplot as plt
import seaborn as sns
from mylibs.jupyter_notebook_helper import show_graph, renderStatsList, renderStatsCollection, \
    renderStatsListWithLabels, renderStatsCollectionOfCrossValids, plot_res_gp, my_plot_convergence
from tensorflow.contrib import rnn
from tensorflow.contrib import learn
import shutil
from tensorflow.contrib.learn.python.learn import learn_runner
from mylibs.tf_helper import getDefaultGPUconfig
from sklearn.metrics import r2_score
from mylibs.py_helper import factors
from fastdtw import fastdtw
from collections import OrderedDict
from scipy.spatial.distance import euclidean
from statsmodels.tsa.stattools import coint
from common import get_or_run_nn
from data_providers.data_provider_27_price_history_mobattrs_date import PriceHistoryMobAttrsDateDataProvider
from data_providers.price_history_dataset_generator import PriceHistoryDatasetGenerator
from skopt.space.space import Integer, Real
from skopt import gp_minimize
from skopt.plots import plot_convergence
import pickle
import inspect
import dill
import sys
from models.model_27_price_history_mobattrs_date import PriceHistoryMobAttrsDateModel
from gp_opt.price_history_27_gp_opt import PriceHistoryGpOpt
# Out:
# /home/studenthp/anaconda2/envs/dis/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
dtype = tf.float32
seed = 16011984
random_state = np.random.RandomState(seed=seed)
config = getDefaultGPUconfig()
n_jobs = 1
# %matplotlib inline

# %% [markdown]
# ### Step 0 - hyperparams

# %% [markdown]
# vocab_size is all the potential words you could have (classification for translation case)
# and max sequence length are the SAME thing
#
# decoder RNN hidden units are usually same size as encoder RNN hidden units in translation but for our case it does not seem really to be a relationship there but we can experiment and find out later, not a priority thing right now

# %%
input_len = 60
target_len = 30

batch_size = 300
with_EOS = False

# %%
full_train_size = 55820
train_size = 55800
small_train_size = 6000 #just because of performance reasons, no statistics behind this decision
test_size = 6200

# %% [markdown]
# ### Once generate data

# %%
data_path = '../../../../Dropbox/data'

# %%
ph_data_path = data_path + '/price_history'

# %%
# npz_train_reduced = ph_data_path + '/price_history_mobattrs_date_dp_60to30_62020_6000_train.npz'
# npz_train = ph_data_path + '/price_history_mobattrs_date_dp_60to30_62020_train.npz'
# npz_test = ph_data_path + '/price_history_mobattrs_date_dp_60to30_62020_test.npz'

# %%
#npz_path = ph_data_path + '/price_history_mobattrs_date_dp_60to30_62020_6000'
npz_path = ph_data_path + '/price_history_mobattrs_date_dp_60to30_62020_trimmed'

# %%
npz_train = npz_path + '_train.npz'
assert path.isfile(npz_train)
path.abspath(npz_train)
# Out:
# '/home/studenthp/Dropbox/data/price_history/price_history_mobattrs_date_dp_60to30_62020_trimmed_train.npz'

# %%
# npz_train_full = ph_data_path + '/price_history_mobattrs_date_dp_60to30_62020_train.npz'
# npz_train_trimmed = ph_data_path + '/price_history_mobattrs_date_dp_60to30_62020_trimmed_train.npz'

# %%
# PriceHistoryDatasetGenerator.create_subsampled(inpath=npz_train_full, target_size=55800,
#                                                outpath=npz_train_trimmed, random_state=random_state)

# %% [markdown]
# ### Step 1 - collect data

# %%
# dp = PriceHistoryMobAttrsDateDataProvider(npz_path=npz_path, batch_size=batch_size, with_EOS=with_EOS)
# for data in dp.datalist:
#     print data.shape

# %% [markdown]
# (55800, 60, 7)
# (55800, 139)
# (55800, 30)
# (55800, 30, 6)

# %%
# for item in dp.next():
#     print item.shape

# %% [markdown]
# ### Step 2 - Build model

# %%
model = PriceHistoryMobAttrsDateModel(rng=random_state, dtype=dtype, config=config, with_EOS=with_EOS)

# %%
# graph = model.getGraph(batch_size=batch_size,
#                        num_units = 10,
#                        rnn_hidden_dim = 10,
#                        mobile_attrs_dim = 10,
#                        input_len=input_len,
#                        target_len=target_len)

# %% [markdown]
# 60
# Tensor("inputs/unstack:0", shape=(100, 7), dtype=float32)
#
# Tensor("encoder_rnn_layer/rnn/gru_cell_59/add:0", shape=(100, 10), dtype=float32)
#
# time
# Tensor("decoder_rnn_layer/rnn/while/add:0", shape=(), dtype=int32)
#
# readout inputs
# Tensor("decoder_rnn_layer/rnn/while/readout_input:0", shape=(100, 20), dtype=float32)
#
# readout
# Tensor("decoder_rnn_layer/rnn/while/readout:0", shape=(100, 1), dtype=float32)
#
# decoder_final_loop_state
# Tensor("decoder_rnn_layer/rnn/while/Exit_5:0", shape=(100, 30), dtype=float32)
#
# Tensor("error/SquaredDifference:0", shape=(100, 30), dtype=float32)
#
# Tensor("error/Mean:0", shape=(), dtype=float32)
# Tensor("error/Mean:0", shape=(), dtype=float32)

# %%
#show_graph(graph)

# %% [markdown]
# ## Quick test run

# %%
# def experiment():
#     return model.run(npz_path=ph_data_path + '/price_history_mobattrs_date_dp_60to30_62020_trimmed',
#                      rnn_hidden_dim = 300, #lets say worst case scenario
#                      mobile_attrs_dim = 300, #lets say worst case scenario
#                      epochs=2,
#                      batch_size = batch_size,
#                      enc_num_units = 600, #lets say worst case scenario
#                      dec_num_units = 600, #lets say worst case scenario
#                      input_len=input_len,
#                      target_len=target_len,
#                      learning_rate = 1e-2,
#                      preds_gather_enabled = False,
#                      decoder_first_input = PriceHistoryMobAttrsDateModel.DECODER_FIRST_INPUT.ZEROS,
#                     )
# aa = experiment()

# %% [markdown]
# keep_prob_rnn_out: 1.0
# lamda2: [0.0, 0.0, 0.0]
# learning_rate: 0.01
# enc_num_units: 600
# epochs: 2
# dec_num_units: 600
# keep_prob_readout: 1.0
# End Epoch 01 (453.036 secs): err(train) = 0.095174, current dec_ins_percent_usage: 1.00
# End Epoch 02 (460.136 secs): err(train) = 0.008046, current dec_ins_percent_usage: 0.00

# %% [markdown]
# # Cross Validating

# %%
def plotter(stats_list, label_text):
    _ = renderStatsListWithLabels(stats_list=stats_list, label_text=label_text)
    plt.show()

    _ = renderStatsListWithLabels(stats_list=stats_list, label_text=label_text,
                                  title='Validation Error', kk='error(valid)')
    plt.show()

# %%
obj = PriceHistoryGpOpt(model=model,
                          stats_npy_filename = 'bayes_opt_27_stats_dic',
                          cv_score_dict_npy_filename = 'bayes_opt_27_cv_scores_dic',
                          res_gp_filename = 'bayes_opt_27_res_gp',
                          epochs=10,
                          n_splits=3,
                          bayes_opt_dir=data_path + '/bayes_opt',
                          random_state=random_state,
                          plotter = plotter,
                          npz_path=npz_path,
                          batch_size=batch_size,
                          input_len=input_len,
                          target_len=target_len,
                         )

# %%
opt_res = obj.run_opt(n_random_starts=3, n_calls=20)
# Out:
# num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim, lambads
# params: [403, 0.59204508519866028, 0.8617053777575101, 0.00010362522558050631, 213, 251, 0.77870619624182169, 3.27687742897986e-05, 0.084909565406181525]
# num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim, lambads
# params: [393, 0.62050786179252548, 0.73076274379803818, 8.3587069001675492e-06, 221, 275, 0.00069380379335194035, 0.0027201073406930318, 0.013002660758987785]
# End Epoch 01 (136.679 secs): err(train) = 3.050615, err(valid)=1.135253, current dec_ins_percent_usage: 1.00
# End Epoch 02 (135.840 secs): err(train) = 2.411806, err(valid)=0.799725, current dec_ins_percent_usage: 0.00
# End Epoch 03 (135.844 secs): err(train) = 1.963574, err(valid)=0.571368, current dec_ins_percent_usage: 0.00
# End Epoch 04 (135.798 secs): err(train) = 1.639847, err(valid)=0.434003, current dec_ins_percent_usage: 0.00
# End Epoch 05 (135.803 secs): err(train) = 1.405412, err(valid)=0.325111, current dec_ins_percent_usage: 0.00
# End Epoch 06 (135.841 secs): err(train) = 1.233812, err(valid)=0.244641, current dec_ins_percent_usage: 0.00
# End Epoch 07 (135.821 secs): err(train) = 1.104615, err(valid)=0.189573, current dec_ins_percent_usage: 0.00
# End Epoch 08 (135.827 secs): err(train) = 1.012892, err(valid)=0.150776, current dec_ins_percent_usage: 0.00
# End Epoch 09 (135.820 secs): err(train) = 0.939331, err(valid)=0.123948, current dec_ins_percent_usage: 0.00
# End Epoch 10 (135.765 secs): err(train) = 0.882635, err(valid)=0.104691, current dec_ins_percent_usage: 0.00
# total test error: 0.151458843581
#
# End Epoch 01 (136.367 secs): err(train) = 2.240562, err(valid)=0.822846, current dec_ins_percent_usage: 1.00
# End Epoch 02 (135.675 secs): err(train) = 1.824756, err(valid)=0.596937, current dec_ins_percent_usage: 0.00
# End Epoch 03 (135.782 secs): err(train) = 1.525545, err(valid)=0.448798, current dec_ins_percent_usage: 0.00
# End Epoch 04 (135.683 secs): err(train) = 1.307808, err(valid)=0.342881, current dec_ins_percent_usage: 0.00
# End Epoch 05 (135.760 secs): err(train) = 1.151718, err(valid)=0.263767, current dec_ins_percent_usage: 0.00
# End Epoch 06 (135.704 secs): err(train) = 1.033112, err(valid)=0.206037, current dec_ins_percent_usage: 0.00
# End Epoch 07 (135.688 secs): err(train) = 0.942752, err(valid)=0.162809, current dec_ins_percent_usage: 0.00
# End Epoch 08 (135.706 secs): err(train) = 0.871315, err(valid)=0.132204, current dec_ins_percent_usage: 0.00
# End Epoch 09 (135.655 secs): err(train) = 0.819264, err(valid)=0.108146, current dec_ins_percent_usage: 0.00
# End Epoch 10 (135.697 secs): err(train) = 0.778054, err(valid)=0.089911, current dec_ins_percent_usage: 0.00
# total test error: 0.111745043027
#
# End Epoch 01 (136.401 secs): err(train) = 2.184634, err(valid)=0.676417, current dec_ins_percent_usage: 1.00
# End Epoch 02 (135.790 secs): err(train) = 1.718249, err(valid)=0.490049, current dec_ins_percent_usage: 0.00
# End Epoch 03 (135.749 secs): err(train) = 1.437224, err(valid)=0.377871, current dec_ins_percent_usage: 0.00
# End Epoch 04 (135.739 secs): err(train) = 1.242276, err(valid)=0.283529, current dec_ins_percent_usage: 0.00
# End Epoch 05 (135.735 secs): err(train) = 1.102872, err(valid)=0.223982, current dec_ins_percent_usage: 0.00
# End Epoch 06 (135.760 secs): err(train) = 0.994726, err(valid)=0.186577, current dec_ins_percent_usage: 0.00
# End Epoch 07 (135.800 secs): err(train) = 0.912405, err(valid)=0.155112, current dec_ins_percent_usage: 0.00
# End Epoch 08 (135.730 secs): err(train) = 0.849140, err(valid)=0.128825, current dec_ins_percent_usage: 0.00
# End Epoch 09 (135.731 secs): err(train) = 0.796510, err(valid)=0.111424, current dec_ins_percent_usage: 0.00
# End Epoch 10 (135.820 secs): err(train) = 0.759771, err(valid)=0.097451, current dec_ins_percent_usage: 0.00
# total test error: 0.0999995216487
#
# cv score: 8.00460309493
# num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim, lambads
# params: [595, 0.77101991512057333, 0.72072825220859893, 1.5041782957252536e-06, 271, 275, 0.41844352716705774, 0.028058299117613341, 0.024309666572143382]
# num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim, lambads
# params: [388, 0.96529493563722157, 0.93932223451971475, 1.2175210601311751e-06, 178, 167, 0.00044388685148401307, 0.0001431153847790032, 0.052666498172758813]
# End Epoch 01 (130.085 secs): err(train) = 2.213397, err(valid)=1.750276, current dec_ins_percent_usage: 1.00
# End Epoch 02 (129.510 secs): err(train) = 2.075074, err(valid)=1.555184, current dec_ins_percent_usage: 0.00
# End Epoch 03 (129.533 secs): err(train) = 1.953046, err(valid)=1.382970, current dec_ins_percent_usage: 0.00
# End Epoch 04 (129.467 secs): err(train) = 1.856255, err(valid)=1.251958, current dec_ins_percent_usage: 0.00
# End Epoch 05 (129.433 secs): err(train) = 1.771247, err(valid)=1.146667, current dec_ins_percent_usage: 0.00
# End Epoch 06 (129.448 secs): err(train) = 1.686468, err(valid)=1.060087, current dec_ins_percent_usage: 0.00
# End Epoch 07 (129.478 secs): err(train) = 1.606061, err(valid)=0.974983, current dec_ins_percent_usage: 0.00
# End Epoch 08 (129.507 secs): err(train) = 1.543383, err(valid)=0.905729, current dec_ins_percent_usage: 0.00
# End Epoch 09 (129.441 secs): err(train) = 1.482820, err(valid)=0.858013, current dec_ins_percent_usage: 0.00
# End Epoch 10 (129.484 secs): err(train) = 1.424051, err(valid)=0.822078, current dec_ins_percent_usage: 0.00
# total test error: 0.890718809059
#
# End Epoch 01 (130.223 secs): err(train) = 2.231818, err(valid)=1.746274, current dec_ins_percent_usage: 1.00
# End Epoch 02 (129.555 secs): err(train) = 2.077340, err(valid)=1.580805, current dec_ins_percent_usage: 0.00
# End Epoch 03 (129.573 secs): err(train) = 1.965649, err(valid)=1.418464, current dec_ins_percent_usage: 0.00
# End Epoch 04 (129.487 secs): err(train) = 1.870541, err(valid)=1.292361, current dec_ins_percent_usage: 0.00
# End Epoch 05 (129.522 secs): err(train) = 1.789992, err(valid)=1.199752, current dec_ins_percent_usage: 0.00
# End Epoch 06 (129.576 secs): err(train) = 1.725963, err(valid)=1.126749, current dec_ins_percent_usage: 0.00
# End Epoch 07 (129.618 secs): err(train) = 1.674162, err(valid)=1.065544, current dec_ins_percent_usage: 0.00
# End Epoch 08 (129.538 secs): err(train) = 1.615102, err(valid)=1.017484, current dec_ins_percent_usage: 0.00
# End Epoch 09 (129.546 secs): err(train) = 1.563904, err(valid)=0.974757, current dec_ins_percent_usage: 0.00
# End Epoch 10 (129.599 secs): err(train) = 1.510256, err(valid)=0.932063, current dec_ins_percent_usage: 0.00
# total test error: 1.02516946677
#
# End Epoch 01 (130.229 secs): err(train) = 2.267457, err(valid)=1.823009, current dec_ins_percent_usage: 1.00
# End Epoch 02 (129.640 secs): err(train) = 1.993084, err(valid)=1.488636, current dec_ins_percent_usage: 0.00
# End Epoch 03 (129.654 secs): err(train) = 1.781627, err(valid)=1.158205, current dec_ins_percent_usage: 0.00
# End Epoch 04 (129.691 secs): err(train) = 1.616493, err(valid)=0.943876, current dec_ins_percent_usage: 0.00
# End Epoch 05 (129.679 secs): err(train) = 1.494579, err(valid)=0.821072, current dec_ins_percent_usage: 0.00
# End Epoch 06 (129.619 secs): err(train) = 1.411993, err(valid)=0.749041, current dec_ins_percent_usage: 0.00
# End Epoch 07 (129.670 secs): err(train) = 1.345812, err(valid)=0.697675, current dec_ins_percent_usage: 0.00
# End Epoch 08 (129.653 secs): err(train) = 1.295203, err(valid)=0.656010, current dec_ins_percent_usage: 0.00
# End Epoch 09 (129.636 secs): err(train) = 1.245246, err(valid)=0.620938, current dec_ins_percent_usage: 0.00
# End Epoch 10 (129.679 secs): err(train) = 1.198531, err(valid)=0.590333, current dec_ins_percent_usage: 0.00
# total test error: 0.660344358413
#
# cv score: 20.1960275
# num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim, lambads
# params: [458, 0.56944086665962201, 0.92712675443239845, 0.00044624448121635072, 169, 107, 0.0043098038009384571, 0.002430527475132315, 0.078719304881165034]
# End Epoch 01 (157.936 secs): err(train) = 0.372278, err(valid)=0.027880, current dec_ins_percent_usage: 1.00
# End Epoch 02 (157.452 secs): err(train) = 0.129563, err(valid)=0.021520, current dec_ins_percent_usage: 0.00
# End Epoch 03 (157.394 secs): err(train) = 0.079066, err(valid)=0.019768, current dec_ins_percent_usage: 0.00
# End Epoch 04 (157.377 secs): err(train) = 0.048396, err(valid)=0.014693, current dec_ins_percent_usage: 0.00
# End Epoch 05 (157.380 secs): err(train) = 0.030142, err(valid)=0.012293, current dec_ins_percent_usage: 0.00
# End Epoch 06 (157.445 secs): err(train) = 0.019734, err(valid)=0.010187, current dec_ins_percent_usage: 0.00
# End Epoch 07 (157.334 secs): err(train) = 0.013737, err(valid)=0.008105, current dec_ins_percent_usage: 0.00
# End Epoch 08 (157.440 secs): err(train) = 0.010435, err(valid)=0.008025, current dec_ins_percent_usage: 0.00
# End Epoch 09 (157.381 secs): err(train) = 0.008649, err(valid)=0.007274, current dec_ins_percent_usage: 0.00
# End Epoch 10 (157.419 secs): err(train) = 0.007718, err(valid)=0.006839, current dec_ins_percent_usage: 0.00
# total test error: 0.00676880314225
#
# End Epoch 01 (157.922 secs): err(train) = 0.400564, err(valid)=0.031385, current dec_ins_percent_usage: 1.00
# End Epoch 02 (157.226 secs): err(train) = 0.145545, err(valid)=0.026229, current dec_ins_percent_usage: 0.00
# End Epoch 03 (157.242 secs): err(train) = 0.091457, err(valid)=0.020853, current dec_ins_percent_usage: 0.00
# num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim, lambads
# params: [459, 0.67035219516358835, 0.93847396199203115, 0.00082032345502505515, 169, 108, 0.0075325124528086984, 0.0014765020019595987, 0.10624911592001192]
# End Epoch 01 (159.054 secs): err(train) = 0.182641, err(valid)=0.022804, current dec_ins_percent_usage: 1.00
# End Epoch 02 (158.092 secs): err(train) = 0.043866, err(valid)=0.012336, current dec_ins_percent_usage: 0.00
# End Epoch 03 (158.086 secs): err(train) = 0.018957, err(valid)=0.009080, current dec_ins_percent_usage: 0.00
# End Epoch 04 (158.011 secs): err(train) = 0.010670, err(valid)=0.007851, current dec_ins_percent_usage: 0.00
# End Epoch 05 (158.081 secs): err(train) = 0.007927, err(valid)=0.007350, current dec_ins_percent_usage: 0.00
# End Epoch 06 (158.234 secs): err(train) = 0.007025, err(valid)=0.007123, current dec_ins_percent_usage: 0.00
# End Epoch 07 (158.079 secs): err(train) = 0.006743, err(valid)=0.007088, current dec_ins_percent_usage: 0.00
# End Epoch 08 (158.158 secs): err(train) = 0.006666, err(valid)=0.007035, current dec_ins_percent_usage: 0.00
# End Epoch 09 (158.332 secs): err(train) = 0.006647, err(valid)=0.007049, current dec_ins_percent_usage: 0.00
# End Epoch 10 (158.284 secs): err(train) = 0.006634, err(valid)=0.007034, current dec_ins_percent_usage: 0.00
# total test error: 0.00704367495623
#
# End Epoch 01 (158.572 secs): err(train) = 0.297548, err(valid)=0.027477, current dec_ins_percent_usage: 1.00
# End Epoch 02 (158.210 secs): err(train) = 0.078114, err(valid)=0.015896, current dec_ins_percent_usage: 0.00
# End Epoch 03 (158.118 secs): err(train) = 0.035605, err(valid)=0.013680, current dec_ins_percent_usage: 0.00
# End Epoch 04 (158.027 secs): err(train) = 0.018247, err(valid)=0.009579, current dec_ins_percent_usage: 0.00
# End Epoch 05 (158.006 secs): err(train) = 0.011111, err(valid)=0.008082, current dec_ins_percent_usage: 0.00
# End Epoch 06 (158.030 secs): err(train) = 0.008345, err(valid)=0.007347, current dec_ins_percent_usage: 0.00
# End Epoch 07 (157.979 secs): err(train) = 0.007322, err(valid)=0.007109, current dec_ins_percent_usage: 0.00
# End Epoch 08 (158.026 secs): err(train) = 0.006919, err(valid)=0.006964, current dec_ins_percent_usage: 0.00
# End Epoch 09 (157.914 secs): err(train) = 0.006793, err(valid)=0.006895, current dec_ins_percent_usage: 0.00
# End Epoch 10 (158.063 secs): err(train) = 0.006739, err(valid)=0.006856, current dec_ins_percent_usage: 0.00
# total test error: 0.00685407347496
#
# End Epoch 01 (158.624 secs): err(train) = 0.287246, err(valid)=0.085529, current dec_ins_percent_usage: 1.00
# End Epoch 02 (158.156 secs): err(train) = 0.081751, err(valid)=0.034095, current dec_ins_percent_usage: 0.00
# End Epoch 03 (158.034 secs): err(train) = 0.039193, err(valid)=0.029394, current dec_ins_percent_usage: 0.00
# End Epoch 04 (136.700 secs): err(train) = 0.006850, err(valid)=0.006863, current dec_ins_percent_usage: 0.00
# End Epoch 05 (136.652 secs): err(train) = 0.006844, err(valid)=0.006863, current dec_ins_percent_usage: 0.00
# End Epoch 06 (136.642 secs): err(train) = 0.006845, err(valid)=0.006857, current dec_ins_percent_usage: 0.00
# End Epoch 07 (136.649 secs): err(train) = 0.006851, err(valid)=0.006879, current dec_ins_percent_usage: 0.00
# End Epoch 08 (136.730 secs): err(train) = 0.006848, err(valid)=0.006868, current dec_ins_percent_usage: 0.00
# End Epoch 09 (136.689 secs): err(train) = 0.006849, err(valid)=0.006868, current dec_ins_percent_usage: 0.00
# End Epoch 10 (136.685 secs): err(train) = 0.006848, err(valid)=0.006860, current dec_ins_percent_usage: 0.00
# total test error: 0.006859410434
#
# End Epoch 01 (137.321 secs): err(train) = 0.084703, err(valid)=0.006834, current dec_ins_percent_usage: 1.00
# End Epoch 02 (136.579 secs): err(train) = 0.006856, err(valid)=0.006843, current dec_ins_percent_usage: 0.00
# End Epoch 03 (136.570 secs): err(train) = 0.006862, err(valid)=0.006843, current dec_ins_percent_usage: 0.00
# End Epoch 04 (136.717 secs): err(train) = 0.006866, err(valid)=0.006855, current dec_ins_percent_usage: 0.00
# End Epoch 05 (136.678 secs): err(train) = 0.006865, err(valid)=0.006833, current dec_ins_percent_usage: 0.00
# End Epoch 06 (136.635 secs): err(train) = 0.006866, err(valid)=0.006831, current dec_ins_percent_usage: 0.00
# End Epoch 07 (136.696 secs): err(train) = 0.006864, err(valid)=0.006830, current dec_ins_percent_usage: 0.00
# End Epoch 08 (136.596 secs): err(train) = 0.006868, err(valid)=0.006837, current dec_ins_percent_usage: 0.00
# End Epoch 09 (136.662 secs): err(train) = 0.006871, err(valid)=0.006832, current dec_ins_percent_usage: 0.00
# End Epoch 10 (136.704 secs): err(train) = 0.006866, err(valid)=0.006863, current dec_ins_percent_usage: 0.00
# total test error: 0.00686237666636
#
# cv score: 1.15849521217
# num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim, lambads
# params: [471, 1.0, 1.0, 0.01, 166, 124, 1.0, 1.0000000000000001e-05, 0.045258988515498574]
# End Epoch 01 (163.457 secs): err(train) = 0.093098, err(valid)=2.815082, current dec_ins_percent_usage: 1.00
# End Epoch 02 (162.697 secs): err(train) = 0.006803, err(valid)=2.597740, current dec_ins_percent_usage: 0.00
# End Epoch 03 (162.762 secs): err(train) = 0.006789, err(valid)=0.198218, current dec_ins_percent_usage: 0.00
# End Epoch 04 (162.667 secs): err(train) = 0.006801, err(valid)=0.011230, current dec_ins_percent_usage: 0.00
# End Epoch 05 (162.802 secs): err(train) = 0.006797, err(valid)=0.007541, current dec_ins_percent_usage: 0.00
# End Epoch 06 (162.829 secs): err(train) = 0.006798, err(valid)=0.006957, current dec_ins_percent_usage: 0.00
# End Epoch 07 (162.738 secs): err(train) = 0.006805, err(valid)=0.006927, current dec_ins_percent_usage: 0.00
# End Epoch 08 (162.891 secs): err(train) = 0.006839, err(valid)=0.006918, current dec_ins_percent_usage: 0.00
# End Epoch 09 (162.748 secs): err(train) = 0.006857, err(valid)=0.006937, current dec_ins_percent_usage: 0.00
# End Epoch 10 (162.774 secs): err(train) = 0.006829, err(valid)=0.006946, current dec_ins_percent_usage: 0.00
# total test error: 0.00694519329456
#
# End Epoch 01 (163.419 secs): err(train) = 0.091908, err(valid)=3.172496, current dec_ins_percent_usage: 1.00
# End Epoch 02 (162.835 secs): err(train) = 0.006791, err(valid)=5.262515, current dec_ins_percent_usage: 0.00
# End Epoch 03 (162.689 secs): err(train) = 0.006762, err(valid)=0.018484, current dec_ins_percent_usage: 0.00
# End Epoch 04 (162.747 secs): err(train) = 0.006759, err(valid)=0.008980, current dec_ins_percent_usage: 0.00
# End Epoch 05 (162.831 secs): err(train) = 0.006766, err(valid)=0.007391, current dec_ins_percent_usage: 0.00
# End Epoch 06 (162.769 secs): err(train) = 0.006773, err(valid)=0.007001, current dec_ins_percent_usage: 0.00
# End Epoch 07 (162.817 secs): err(train) = 0.006765, err(valid)=0.007000, current dec_ins_percent_usage: 0.00
# End Epoch 08 (162.853 secs): err(train) = 0.006774, err(valid)=0.006994, current dec_ins_percent_usage: 0.00
# End Epoch 09 (162.810 secs): err(train) = 0.006790, err(valid)=0.006974, current dec_ins_percent_usage: 0.00
# End Epoch 10 (162.812 secs): err(train) = 0.006805, err(valid)=0.007004, current dec_ins_percent_usage: 0.00
# total test error: 0.00700417595855
#
# End Epoch 01 (163.351 secs): err(train) = 0.080798, err(valid)=0.735428, current dec_ins_percent_usage: 1.00
# End Epoch 02 (162.606 secs): err(train) = 0.007012, err(valid)=0.191834, current dec_ins_percent_usage: 0.00
# End Epoch 03 (162.641 secs): err(train) = 0.006886, err(valid)=0.044596, current dec_ins_percent_usage: 0.00
# End Epoch 04 (162.738 secs): err(train) = 0.006884, err(valid)=0.007666, current dec_ins_percent_usage: 0.00
# End Epoch 05 (162.611 secs): err(train) = 0.006890, err(valid)=0.006764, current dec_ins_percent_usage: 0.00
# End Epoch 06 (162.633 secs): err(train) = 0.006902, err(valid)=0.006732, current dec_ins_percent_usage: 0.00
# End Epoch 07 (162.691 secs): err(train) = 0.006903, err(valid)=0.006728, current dec_ins_percent_usage: 0.00
# End Epoch 08 (162.546 secs): err(train) = 0.006903, err(valid)=0.006745, current dec_ins_percent_usage: 0.00
# End Epoch 09 (162.637 secs): err(train) = 0.006943, err(valid)=0.006732, current dec_ins_percent_usage: 0.00
# End Epoch 10 (162.653 secs): err(train) = 0.006936, err(valid)=0.006741, current dec_ins_percent_usage: 0.00
# total test error: 0.00674133240846
#
# cv score: 1.16444149954
# num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim, lambads
# params: [497, 1.0, 1.0, 0.01, 165, 251, 1.0095435894013478e-05, 0.27264650191949696, 1.0]
# End Epoch 01 (177.208 secs): err(train) = 0.249267, err(valid)=0.007009, current dec_ins_percent_usage: 1.00
# End Epoch 02 (176.664 secs): err(train) = 0.006737, err(valid)=0.006940, current dec_ins_percent_usage: 0.00
# End Epoch 03 (176.735 secs): err(train) = 0.006754, err(valid)=0.007004, current dec_ins_percent_usage: 0.00
# End Epoch 04 (176.710 secs): err(train) = 0.006742, err(valid)=0.006904, current dec_ins_percent_usage: 0.00
# num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim, lambads
# params: [390, 1.0, 0.89271753615835747, 0.01, 161, 215, 1.0, 1.0, 1.0]
# End Epoch 01 (131.283 secs): err(train) = 0.132502, err(valid)=0.006995, current dec_ins_percent_usage: 1.00
# End Epoch 02 (130.618 secs): err(train) = 0.006771, err(valid)=0.006994, current dec_ins_percent_usage: 0.00
# End Epoch 03 (130.543 secs): err(train) = 0.006777, err(valid)=0.006995, current dec_ins_percent_usage: 0.00
# End Epoch 04 (130.647 secs): err(train) = 0.006782, err(valid)=0.006992, current dec_ins_percent_usage: 0.00
# End Epoch 05 (130.605 secs): err(train) = 0.006776, err(valid)=0.006994, current dec_ins_percent_usage: 0.00
# End Epoch 06 (130.575 secs): err(train) = 0.006786, err(valid)=0.006992, current dec_ins_percent_usage: 0.00
# End Epoch 07 (130.641 secs): err(train) = 0.006783, err(valid)=0.006990, current dec_ins_percent_usage: 0.00
# End Epoch 08 (130.582 secs): err(train) = 0.006785, err(valid)=0.006998, current dec_ins_percent_usage: 0.00
# End Epoch 09 (130.614 secs): err(train) = 0.006785, err(valid)=0.006995, current dec_ins_percent_usage: 0.00
# End Epoch 10 (130.604 secs): err(train) = 0.006790, err(valid)=0.006997, current dec_ins_percent_usage: 0.00
# total test error: 0.00699627132065
#
# End Epoch 01 (131.244 secs): err(train) = 0.086774, err(valid)=0.006834, current dec_ins_percent_usage: 1.00
# End Epoch 02 (130.460 secs): err(train) = 0.006870, err(valid)=0.006830, current dec_ins_percent_usage: 0.00
# End Epoch 03 (130.497 secs): err(train) = 0.006869, err(valid)=0.006838, current dec_ins_percent_usage: 0.00
# End Epoch 04 (130.566 secs): err(train) = 0.006872, err(valid)=0.006838, current dec_ins_percent_usage: 0.00
# End Epoch 05 (130.483 secs): err(train) = 0.006872, err(valid)=0.006828, current dec_ins_percent_usage: 0.00
# End Epoch 06 (130.545 secs): err(train) = 0.006870, err(valid)=0.006843, current dec_ins_percent_usage: 0.00
# End Epoch 07 (130.606 secs): err(train) = 0.006872, err(valid)=0.006868, current dec_ins_percent_usage: 0.00
# End Epoch 08 (130.515 secs): err(train) = 0.006874, err(valid)=0.006827, current dec_ins_percent_usage: 0.00
# End Epoch 09 (130.568 secs): err(train) = 0.006879, err(valid)=0.006824, current dec_ins_percent_usage: 0.00
# End Epoch 10 (130.597 secs): err(train) = 0.006875, err(valid)=0.006820, current dec_ins_percent_usage: 0.00
# total test error: 0.00681948046681
#
# End Epoch 01 (131.186 secs): err(train) = 0.081307, err(valid)=0.006838, current dec_ins_percent_usage: 1.00
# End Epoch 02 (130.541 secs): err(train) = 0.006846, err(valid)=0.006839, current dec_ins_percent_usage: 0.00
# End Epoch 03 (130.445 secs): err(train) = 0.006847, err(valid)=0.006837, current dec_ins_percent_usage: 0.00
# End Epoch 04 (130.562 secs): err(train) = 0.006850, err(valid)=0.006855, current dec_ins_percent_usage: 0.00
# End Epoch 05 (130.465 secs): err(train) = 0.006841, err(valid)=0.006858, current dec_ins_percent_usage: 0.00
# total test error: 0.00696217337803
#
# End Epoch 01 (141.074 secs): err(train) = 0.167176, err(valid)=0.007239, current dec_ins_percent_usage: 1.00
# End Epoch 02 (140.389 secs): err(train) = 0.007468, err(valid)=0.006997, current dec_ins_percent_usage: 0.00
# End Epoch 03 (140.413 secs): err(train) = 0.006754, err(valid)=0.006999, current dec_ins_percent_usage: 0.00
# End Epoch 04 (140.398 secs): err(train) = 0.006758, err(valid)=0.006995, current dec_ins_percent_usage: 0.00
# End Epoch 05 (140.396 secs): err(train) = 0.006748, err(valid)=0.006992, current dec_ins_percent_usage: 0.00
# End Epoch 06 (140.429 secs): err(train) = 0.006766, err(valid)=0.006999, current dec_ins_percent_usage: 0.00
# End Epoch 07 (140.404 secs): err(train) = 0.006760, err(valid)=0.007071, current dec_ins_percent_usage: 0.00
# End Epoch 08 (140.514 secs): err(train) = 0.006763, err(valid)=0.007023, current dec_ins_percent_usage: 0.00
# End Epoch 09 (140.439 secs): err(train) = 0.006781, err(valid)=0.007015, current dec_ins_percent_usage: 0.00
# End Epoch 10 (140.374 secs): err(train) = 0.006785, err(valid)=0.007013, current dec_ins_percent_usage: 0.00
# total test error: 0.00701332126083
#
# cv score: 1.18388432168
# num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim, lambads
# params: [463, 0.9687900071449741, 0.95796291688143509, 0.0038556941903822727, 168, 113, 0.035455651473530379, 0.00038565109912099883, 0.22593710252578925]
# End Epoch 01 (160.010 secs): err(train) = 0.127422, err(valid)=0.007786, current dec_ins_percent_usage: 1.00
# End Epoch 02 (159.349 secs): err(train) = 0.007542, err(valid)=0.006941, current dec_ins_percent_usage: 0.00
# End Epoch 03 (159.316 secs): err(train) = 0.006783, err(valid)=0.006941, current dec_ins_percent_usage: 0.00
# End Epoch 04 (159.373 secs): err(train) = 0.006769, err(valid)=0.006959, current dec_ins_percent_usage: 0.00
# End Epoch 05 (159.415 secs): err(train) = 0.006797, err(valid)=0.006934, current dec_ins_percent_usage: 0.00
# End Epoch 06 (159.279 secs): err(train) = 0.006824, err(valid)=0.006929, current dec_ins_percent_usage: 0.00
# End Epoch 07 (159.436 secs): err(train) = 0.006834, err(valid)=0.006952, current dec_ins_percent_usage: 0.00
# End Epoch 08 (159.348 secs): err(train) = 0.006820, err(valid)=0.006934, current dec_ins_percent_usage: 0.00
# End Epoch 09 (159.378 secs): err(train) = 0.006800, err(valid)=0.006949, current dec_ins_percent_usage: 0.00
# End Epoch 10 (159.342 secs): err(train) = 0.006854, err(valid)=0.006998, current dec_ins_percent_usage: 0.00
# total test error: 0.00700655897268
#
# End Epoch 01 (160.021 secs): err(train) = 0.103577, err(valid)=0.007069, current dec_ins_percent_usage: 1.00
# End Epoch 02 (159.355 secs): err(train) = 0.007419, err(valid)=0.006840, current dec_ins_percent_usage: 0.00
# End Epoch 03 (159.316 secs): err(train) = 0.006910, err(valid)=0.006711, current dec_ins_percent_usage: 0.00
# End Epoch 04 (159.318 secs): err(train) = 0.006885, err(valid)=0.006719, current dec_ins_percent_usage: 0.00
# End Epoch 05 (159.359 secs): err(train) = 0.006903, err(valid)=0.006725, current dec_ins_percent_usage: 0.00
# End Epoch 06 (159.340 secs): err(train) = 0.006903, err(valid)=0.006718, current dec_ins_percent_usage: 0.00
# End Epoch 07 (159.336 secs): err(train) = 0.006938, err(valid)=0.006676, current dec_ins_percent_usage: 0.00
# End Epoch 08 (159.346 secs): err(train) = 0.006961, err(valid)=0.006898, current dec_ins_percent_usage: 0.00
# End Epoch 09 (159.406 secs): err(train) = 0.006985, err(valid)=0.006847, current dec_ins_percent_usage: 0.00
# End Epoch 10 (159.307 secs): err(train) = 0.006925, err(valid)=0.006760, current dec_ins_percent_usage: 0.00
# total test error: 0.00676120644916
#
# End Epoch 01 (160.079 secs): err(train) = 0.143944, err(valid)=0.007443, current dec_ins_percent_usage: 1.00
# End Epoch 02 (159.243 secs): err(train) = 0.007721, err(valid)=0.007004, current dec_ins_percent_usage: 0.00
# End Epoch 03 (159.286 secs): err(train) = 0.006719, err(valid)=0.007051, current dec_ins_percent_usage: 0.00
# End Epoch 04 (159.357 secs): err(train) = 0.006726, err(valid)=0.007132, current dec_ins_percent_usage: 0.00
# End Epoch 05 (159.312 secs): err(train) = 0.006751, err(valid)=0.007014, current dec_ins_percent_usage: 0.00
# End Epoch 06 (159.267 secs): err(train) = 0.006738, err(valid)=0.007005, current dec_ins_percent_usage: 0.00
# End Epoch 07 (159.329 secs): err(train) = 0.006748, err(valid)=0.007021, current dec_ins_percent_usage: 0.00
# End Epoch 08 (159.262 secs): err(train) = 0.006771, err(valid)=0.007039, current dec_ins_percent_usage: 0.00
# End Epoch 09 (159.294 secs): err(train) = 0.006782, err(valid)=0.006993, current dec_ins_percent_usage: 0.00
# End Epoch 10 (159.330 secs): err(train) = 0.006780, err(valid)=0.007008, current dec_ins_percent_usage: 0.00
# total test error: 0.00700496532203
#
# cv score: 1.21212177423
# num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim, lambads
# params: [406, 0.56347883474568417, 0.91489288133622981, 0.0018353179117074441, 207, 254, 1.0, 5.7030245345554468e-05, 0.53035796770148869]
# ...
# End Epoch 08 (137.877 secs): err(train) = 0.006894, err(valid)=0.006779, current dec_ins_percent_usage: 0.00
# End Epoch 09 (138.208 secs): err(train) = 0.006876, err(valid)=0.006778, current dec_ins_percent_usage: 0.00
# End Epoch 10 (138.170 secs): err(train) = 0.006883, err(valid)=0.006768, current dec_ins_percent_usage: 0.00
# total test error: 0.00676628592003
#
# End Epoch 01 (139.115 secs): err(train) = 0.147255, err(valid)=0.006779, current dec_ins_percent_usage: 1.00
# End Epoch 02 (138.403 secs): err(train) = 0.008164, err(valid)=0.006782, current dec_ins_percent_usage: 0.00
# End Epoch 03 (138.290 secs): err(train) = 0.006848, err(valid)=0.006788, current dec_ins_percent_usage: 0.00
# End Epoch 04 (138.441 secs): err(train) = 0.006862, err(valid)=0.006782, current dec_ins_percent_usage: 0.00
# End Epoch 05 (138.477 secs): err(train) = 0.006861, err(valid)=0.006784, current dec_ins_percent_usage: 0.00
# End Epoch 06 (138.444 secs): err(train) = 0.006855, err(valid)=0.006784, current dec_ins_percent_usage: 0.00
# End Epoch 07 (138.193 secs): err(train) = 0.006883, err(valid)=0.006789, current dec_ins_percent_usage: 0.00
# End Epoch 08 (138.122 secs): err(train) = 0.006876, err(valid)=0.006782, current dec_ins_percent_usage: 0.00
# End Epoch 09 (138.161 secs): err(train) = 0.006882, err(valid)=0.006786, current dec_ins_percent_usage: 0.00
# End Epoch 10 (138.141 secs): err(train) = 0.006894, err(valid)=0.006782, current dec_ins_percent_usage: 0.00
# total test error: 0.00678288223102
#
# cv score: 1.19708355498
# num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim, lambads
# params: [471, 0.5, 0.92369473296821913, 0.0010822053759626399, 164, 113, 0.021905339149095964, 0.001432156061494345, 0.02179574537287552]
# End Epoch 01 (163.077 secs): err(train) = 0.256395, err(valid)=0.031775, current dec_ins_percent_usage: 1.00
# End Epoch 02 (162.347 secs): err(train) = 0.068131, err(valid)=0.034103, current dec_ins_percent_usage: 0.00
# End Epoch 03 (162.265 secs): err(train) = 0.027591, err(valid)=0.021461, current dec_ins_percent_usage: 0.00
# End Epoch 04 (162.297 secs): err(train) = 0.012961, err(valid)=0.012430, current dec_ins_percent_usage: 0.00
# End Epoch 05 (162.426 secs): err(train) = 0.008602, err(valid)=0.010043, current dec_ins_percent_usage: 0.00
# End Epoch 06 (162.401 secs): err(train) = 0.007299, err(valid)=0.008298, current dec_ins_percent_usage: 0.00
# End Epoch 07 (162.400 secs): err(train) = 0.006904, err(valid)=0.008062, current dec_ins_percent_usage: 0.00
# End Epoch 08 (162.328 secs): err(train) = 0.006787, err(valid)=0.007213, current dec_ins_percent_usage: 0.00
# End Epoch 09 (162.388 secs): err(train) = 0.006737, err(valid)=0.007038, current dec_ins_percent_usage: 0.00
# End Epoch 10 (162.338 secs): err(train) = 0.006726, err(valid)=0.006981, current dec_ins_percent_usage: 0.00
# total test error: 0.00696099205543
#
# End Epoch 01 (163.012 secs): err(train) = 0.220398, err(valid)=0.019015, current dec_ins_percent_usage: 1.00
# End Epoch 02 (162.296 secs): err(train) = 0.057620, err(valid)=0.024760, current dec_ins_percent_usage: 0.00
# End Epoch 03 (162.292 secs): err(train) = 0.023341, err(valid)=0.014136, current dec_ins_percent_usage: 0.00
# End Epoch 04 (162.267 secs): err(train) = 0.011660, err(valid)=0.010210, current dec_ins_percent_usage: 0.00
# End Epoch 05 (162.301 secs): err(train) = 0.008257, err(valid)=0.007858, current dec_ins_percent_usage: 0.00
# End Epoch 06 (162.255 secs): err(train) = 0.007242, err(valid)=0.007355, current dec_ins_percent_usage: 0.00
# End Epoch 07 (162.298 secs): err(train) = 0.006933, err(valid)=0.007002, current dec_ins_percent_usage: 0.00
# End Epoch 08 (162.295 secs): err(train) = 0.006854, err(valid)=0.006774, current dec_ins_percent_usage: 0.00
# End Epoch 09 (162.205 secs): err(train) = 0.006829, err(valid)=0.006725, current dec_ins_percent_usage: 0.00
# End Epoch 10 (162.318 secs): err(train) = 0.006825, err(valid)=0.006685, current dec_ins_percent_usage: 0.00
# total test error: 0.00668675115993
#
# End Epoch 01 (162.867 secs): err(train) = 0.213538, err(valid)=0.098277, current dec_ins_percent_usage: 1.00
# End Epoch 02 (162.206 secs): err(train) = 0.057156, err(valid)=0.040934, current dec_ins_percent_usage: 0.00
# End Epoch 03 (162.192 secs): err(train) = 0.023899, err(valid)=0.017334, current dec_ins_percent_usage: 0.00
# End Epoch 04 (162.198 secs): err(train) = 0.012240, err(valid)=0.010190, current dec_ins_percent_usage: 0.00
# End Epoch 05 (162.150 secs): err(train) = 0.008521, err(valid)=0.008214, current dec_ins_percent_usage: 0.00
# End Epoch 06 (162.175 secs): err(train) = 0.007376, err(valid)=0.007374, current dec_ins_percent_usage: 0.00
# End Epoch 07 (162.234 secs): err(train) = 0.006901, err(valid)=0.007078, current dec_ins_percent_usage: 0.00
# End Epoch 08 (162.247 secs): err(train) = 0.006740, err(valid)=0.007040, current dec_ins_percent_usage: 0.00
# End Epoch 09 (162.273 secs): err(train) = 0.006683, err(valid)=0.007021, current dec_ins_percent_usage: 0.00
# End Epoch 10 (162.277 secs): err(train) = 0.006663, err(valid)=0.007001, current dec_ins_percent_usage: 0.00
# total test error: 0.00700147440206
#
# cv score: 1.17654024042
# num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim, lambads
# params: [500, 1.0, 1.0, 0.01, 162, 190, 0.12177016015529381, 6.755665441653591e-05, 0.32141321728446759]
# End Epoch 01 (175.802 secs): err(train) = 0.194485, err(valid)=0.067920, current dec_ins_percent_usage: 1.00
# End Epoch 02 (175.382 secs): err(train) = 0.006918, err(valid)=0.007237, current dec_ins_percent_usage: 0.00
# End Epoch 03 (175.310 secs): err(train) = 0.006874, err(valid)=0.006678, current dec_ins_percent_usage: 0.00
# End Epoch 04 (175.375 secs): err(train) = 0.006896, err(valid)=0.006660, current dec_ins_percent_usage: 0.00
# End Epoch 05 (175.274 secs): err(train) = 0.006910, err(valid)=0.006666, current dec_ins_percent_usage: 0.00
# End Epoch 06 (175.207 secs): err(train) = 0.006914, err(valid)=0.006652, current dec_ins_percent_usage: 0.00
# End Epoch 07 (175.297 secs): err(train) = 0.006919, err(valid)=0.006666, current dec_ins_percent_usage: 0.00
# End Epoch 08 (175.304 secs): err(train) = 0.006932, err(valid)=0.006677, current dec_ins_percent_usage: 0.00
# End Epoch 09 (175.248 secs): err(train) = 0.006965, err(valid)=0.006663, current dec_ins_percent_usage: 0.00
# End Epoch 10 (175.280 secs): err(train) = 0.006994, err(valid)=0.006676, current dec_ins_percent_usage: 0.00
# total test error: 0.00667532365168
#
# End Epoch 01 (176.006 secs): err(train) = 0.144528, err(valid)=0.022187, current dec_ins_percent_usage: 1.00
# End Epoch 02 (175.321 secs): err(train) = 0.006814, err(valid)=0.006910, current dec_ins_percent_usage: 0.00
# End Epoch 03 (175.287 secs): err(train) = 0.006827, err(valid)=0.006828, current dec_ins_percent_usage: 0.00
# End Epoch 04 (175.374 secs): err(train) = 0.006834, err(valid)=0.006827, current dec_ins_percent_usage: 0.00
# End Epoch 05 (175.266 secs): err(train) = 0.006846, err(valid)=0.006844, current dec_ins_percent_usage: 0.00
# End Epoch 06 (175.382 secs): err(train) = 0.006876, err(valid)=0.006817, current dec_ins_percent_usage: 0.00
# End Epoch 07 (175.275 secs): err(train) = 0.006858, err(valid)=0.006824, current dec_ins_percent_usage: 0.00
# End Epoch 08 (175.347 secs): err(train) = 0.006885, err(valid)=0.006827, current dec_ins_percent_usage: 0.00
# End Epoch 09 (175.339 secs): err(train) = 0.006933, err(valid)=0.006811, current dec_ins_percent_usage: 0.00
# End Epoch 10 (175.420 secs): err(train) = 0.006885, err(valid)=0.006811, current dec_ins_percent_usage: 0.00
# total test error: 0.0068094709122
#
# End Epoch 01 (175.856 secs): err(train) = 0.097148, err(valid)=0.007204, current dec_ins_percent_usage: 1.00
# End Epoch 02 (175.377 secs): err(train) = 0.006659, err(valid)=0.007157, current dec_ins_percent_usage: 0.00
# End Epoch 03 (175.270 secs): err(train) = 0.006662, err(valid)=0.007150, current dec_ins_percent_usage: 0.00
# End Epoch 04 (175.429 secs): err(train) = 0.006701, err(valid)=0.007142, current dec_ins_percent_usage: 0.00
# End Epoch 05 (175.318 secs): err(train) = 0.006700, err(valid)=0.007164, current dec_ins_percent_usage: 0.00
# End Epoch 06 (175.286 secs): err(train) = 0.006718, err(valid)=0.007149, current dec_ins_percent_usage: 0.00
# End Epoch 07 (175.341 secs): err(train) = 0.006741, err(valid)=0.007136, current dec_ins_percent_usage: 0.00
# End Epoch 08 (175.356 secs): err(train) = 0.006783, err(valid)=0.007166, current dec_ins_percent_usage: 0.00
# End Epoch 09 (175.376 secs): err(train) = 0.006747, err(valid)=0.007152, current dec_ins_percent_usage: 0.00
# End Epoch 10 (175.305 secs): err(train) = 0.006905, err(valid)=0.007150, current dec_ins_percent_usage: 0.00
# total test error: 0.0071528895022
#
# cv score: 1.17659247516
# num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim, lambads
# params: [459, 1.0, 0.96532412555041802, 0.01, 166, 133, 1.0, 1.0000000000000001e-05, 0.015191930312706287]
# End Epoch 01 (158.794 secs): err(train) = 0.127260, err(valid)=0.010322, current dec_ins_percent_usage: 1.00
# End Epoch 02 (158.245 secs): err(train) = 0.008911, err(valid)=7.413064, current dec_ins_percent_usage: 0.00
# End Epoch 03 (158.318 secs): err(train) = 0.006786, err(valid)=4.055921, current dec_ins_percent_usage: 0.00
# End Epoch 04 (158.263 secs): err(train) = 0.006790, err(valid)=0.111965, current dec_ins_percent_usage: 0.00
# End Epoch 05 (158.289 secs): err(train) = 0.006782, err(valid)=0.047908, current dec_ins_percent_usage: 0.00
# End Epoch 06 (158.309 secs): err(train) = 0.006780, err(valid)=0.459838, current dec_ins_percent_usage: 0.00
# End Epoch 07 (158.003 secs): err(train) = 0.006786, err(valid)=0.007123, current dec_ins_percent_usage: 0.00
# End Epoch 08 (157.581 secs): err(train) = 0.006809, err(valid)=0.006967, current dec_ins_percent_usage: 0.00
# End Epoch 09 (157.674 secs): err(train) = 0.006820, err(valid)=0.007075, current dec_ins_percent_usage: 0.00
# End Epoch 10 (157.493 secs): err(train) = 0.006820, err(valid)=0.007089, current dec_ins_percent_usage: 0.00
# total test error: 0.00695692889032
#
# End Epoch 01 (158.215 secs): err(train) = 0.120243, err(valid)=0.224003, current dec_ins_percent_usage: 1.00
# End Epoch 02 (157.604 secs): err(train) = 0.007306, err(valid)=1.927173, current dec_ins_percent_usage: 0.00
# End Epoch 03 (157.529 secs): err(train) = 0.006845, err(valid)=0.477666, current dec_ins_percent_usage: 0.00
# End Epoch 04 (157.690 secs): err(train) = 0.006837, err(valid)=0.076126, current dec_ins_percent_usage: 0.00
# End Epoch 05 (159.503 secs): err(train) = 0.006833, err(valid)=0.195257, current dec_ins_percent_usage: 0.00
# End Epoch 06 (164.699 secs): err(train) = 0.006847, err(valid)=0.525701, current dec_ins_percent_usage: 0.00
# End Epoch 07 (158.103 secs): err(train) = 0.006836, err(valid)=0.012853, current dec_ins_percent_usage: 0.00
# End Epoch 08 (158.025 secs): err(train) = 0.006838, err(valid)=0.008525, current dec_ins_percent_usage: 0.00
# End Epoch 09 (158.086 secs): err(train) = 0.006855, err(valid)=0.006853, current dec_ins_percent_usage: 0.00
# End Epoch 10 (158.054 secs): err(train) = 0.006897, err(valid)=0.006857, current dec_ins_percent_usage: 0.00
# total test error: 0.00685806115789
#
# End Epoch 01 (158.567 secs): err(train) = 0.121758, err(valid)=0.207787, current dec_ins_percent_usage: 1.00
# End Epoch 02 (157.955 secs): err(train) = 0.006898, err(valid)=0.137959, current dec_ins_percent_usage: 0.00
# End Epoch 03 (158.200 secs): err(train) = 0.006881, err(valid)=1.397965, current dec_ins_percent_usage: 0.00
# End Epoch 04 (158.019 secs): err(train) = 0.006876, err(valid)=0.429561, current dec_ins_percent_usage: 0.00
# End Epoch 05 (158.147 secs): err(train) = 0.006885, err(valid)=0.751501, current dec_ins_percent_usage: 0.00
# End Epoch 06 (158.548 secs): err(train) = 0.006865, err(valid)=1.037580, current dec_ins_percent_usage: 0.00
# End Epoch 07 (158.151 secs): err(train) = 0.006868, err(valid)=0.069254, current dec_ins_percent_usage: 0.00
# End Epoch 08 (158.138 secs): err(train) = 0.006860, err(valid)=0.007263, current dec_ins_percent_usage: 0.00
# End Epoch 09 (158.133 secs): err(train) = 0.006878, err(valid)=0.007992, current dec_ins_percent_usage: 0.00
# End Epoch 10 (158.241 secs): err(train) = 0.006889, err(valid)=0.016856, current dec_ins_percent_usage: 0.00
# total test error: 0.00710286501975
#
# cv score: 1.2646821259
# num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim, lambads
# params: [410, 0.99981003203947472, 0.99923455047136445, 0.01, 168, 200, 1.0, 0.00049485145259653592, 1.0]
# End Epoch 01 (136.061 secs): err(train) = 0.084250, err(valid)=0.006736, current dec_ins_percent_usage: 1.00
# End Epoch 02 (135.304 secs): err(train) = 0.006914, err(valid)=0.006861, current dec_ins_percent_usage: 0.00
# End Epoch 03 (135.330 secs): err(train) = 0.006930, err(valid)=0.006736, current dec_ins_percent_usage: 0.00
# End Epoch 04 (135.345 secs): err(train) = 0.006919, err(valid)=0.006766, current dec_ins_percent_usage: 0.00
# End Epoch 05 (135.344 secs): err(train) = 0.006913, err(valid)=0.006734, current dec_ins_percent_usage: 0.00
# End Epoch 06 (135.402 secs): err(train) = 0.006918, err(valid)=0.006740, current dec_ins_percent_usage: 0.00
# End Epoch 07 (135.422 secs): err(train) = 0.006918, err(valid)=0.006732, current dec_ins_percent_usage: 0.00
# End Epoch 08 (135.408 secs): err(train) = 0.006939, err(valid)=0.006762, current dec_ins_percent_usage: 0.00
# End Epoch 09 (135.423 secs): err(train) = 0.006921, err(valid)=0.006757, current dec_ins_percent_usage: 0.00
# End Epoch 10 (135.390 secs): err(train) = 0.006932, err(valid)=0.006741, current dec_ins_percent_usage: 0.00
# total test error: 0.0067411994171
#
# End Epoch 01 (136.138 secs): err(train) = 0.140204, err(valid)=0.007171, current dec_ins_percent_usage: 1.00
# End Epoch 02 (135.254 secs): err(train) = 0.006858, err(valid)=0.007052, current dec_ins_percent_usage: 0.00
# End Epoch 03 (135.367 secs): err(train) = 0.006891, err(valid)=0.007397, current dec_ins_percent_usage: 0.00
# End Epoch 04 (135.954 secs): err(train) = 0.006872, err(valid)=0.006968, current dec_ins_percent_usage: 0.00
# End Epoch 05 (135.344 secs): err(train) = 0.006840, err(valid)=0.006942, current dec_ins_percent_usage: 0.00
# End Epoch 06 (135.538 secs): err(train) = 0.006824, err(valid)=0.006946, current dec_ins_percent_usage: 0.00
# End Epoch 07 (135.444 secs): err(train) = 0.006824, err(valid)=0.006985, current dec_ins_percent_usage: 0.00
# End Epoch 08 (135.467 secs): err(train) = 0.006824, err(valid)=0.006965, current dec_ins_percent_usage: 0.00
# End Epoch 09 (135.470 secs): err(train) = 0.006848, err(valid)=0.006948, current dec_ins_percent_usage: 0.00
# End Epoch 10 (135.460 secs): err(train) = 0.006829, err(valid)=0.006972, current dec_ins_percent_usage: 0.00
# total test error: 0.0069716483685
#
# End Epoch 01 (136.048 secs): err(train) = 0.108203, err(valid)=0.006997, current dec_ins_percent_usage: 1.00
# End Epoch 02 (135.247 secs): err(train) = 0.006773, err(valid)=0.006987, current dec_ins_percent_usage: 0.00
# End Epoch 03 (135.252 secs): err(train) = 0.006777, err(valid)=0.006988, current dec_ins_percent_usage: 0.00
# End Epoch 04 (135.221 secs): err(train) = 0.006778, err(valid)=0.006986, current dec_ins_percent_usage: 0.00
# End Epoch 05 (135.251 secs): err(train) = 0.006779, err(valid)=0.006983, current dec_ins_percent_usage: 0.00
# End Epoch 06 (135.310 secs): err(train) = 0.006780, err(valid)=0.006999, current dec_ins_percent_usage: 0.00
# End Epoch 07 (135.269 secs): err(train) = 0.006786, err(valid)=0.006994, current dec_ins_percent_usage: 0.00
# End Epoch 08 (134.940 secs): err(train) = 0.006784, err(valid)=0.006994, current dec_ins_percent_usage: 0.00
# End Epoch 09 (135.230 secs): err(train) = 0.006786, err(valid)=0.006987, current dec_ins_percent_usage: 0.00
# End Epoch 10 (135.281 secs): err(train) = 0.006786, err(valid)=0.006986, current dec_ins_percent_usage: 0.00
# total test error: 0.00698630981928
#
# cv score: 1.24042383053

# %%
plot_res_gp(opt_res)

# %%
opt_res.best_params
# Out:
# [415, 1.0, 1.0, 0.01, 168, 182, 1.0, 1.0000000000000001e-05, 1.0]

# %%
filepath = data_path + '/bayes_opt' + '/bayes_opt_27_stats_dic.npy'
assert path.isfile(filepath)

# %%
renderStatsCollectionOfCrossValids(stats_dic=np.load(filepath)[()], label_texts=[
    'n_units', 'prob_rnn_out', 'prob_readout', 'lr', 'rnn_hidden_dim', 'mobattrs_dim', 'l2_0', 'l2_1', 'l2_2',
])
plt.show()

# %% [markdown]
# ### Step 3 training the network

# %%
model = PriceHistoryMobAttrsDateModel(rng=random_state, dtype=dtype, config=config, with_EOS=with_EOS)

# %%
if 'opt_res' in locals():
    print "defined above"
    best_params = opt_res.best_params
else:
    print "hardcoded"
    best_params = [415, 1.0, 1.0, 0.01, 168, 182, 1.0, 1.0000000000000001e-05, 1.0]
# Out:
# hardcoded

# %%
num_units, keep_prob_rnn_out, keep_prob_readout, learning_rate, rnn_hidden_dim, mobile_attrs_dim = best_params[
                                                                                :-PriceHistoryGpOpt.LAMDA2_COUNT]

# %%
lamda2_list = best_params[-PriceHistoryGpOpt.LAMDA2_COUNT:]

# %%
batch_size
# Out:
# 300

# %%
npz_test = npz_path[:-len('_trimmed')] + '_test.npz'
assert path.isfile(npz_test)
path.abspath(npz_test)
# Out:
# '/home/studenthp/Dropbox/data/price_history/price_history_mobattrs_date_dp_60to30_62020_test.npz'

# %%
# npz_test_trimmed = npz_test[:-len('_test.npz')] + '_trimmed' + '_test.npz'
# npz_test_trimmed
# PriceHistoryDatasetGenerator.create_subsampled(inpath=npz_test, target_size=6000,
#     outpath=npz_test_trimmed, random_state=random_state)

# %%
def experiment():
    return model.train_predict(npz_path=npz_path,
             epochs=10,
             batch_size = batch_size,
             num_units=num_units,
             input_len=input_len,
             target_len=target_len,
             learning_rate = learning_rate,
             batch_norm_enabled = True,
             decoder_first_input = PriceHistoryMobAttrsDateModel.DECODER_FIRST_INPUT.ZEROS,
             keep_prob_rnn_out=keep_prob_rnn_out,
             keep_prob_readout=keep_prob_readout,
             rnn_hidden_dim = rnn_hidden_dim,
             mobile_attrs_dim = mobile_attrs_dim,
             lamda2 = lamda2_list,
             plotting = True,
             dec_inputs_part = True,
            )

# %%
#%%time
dyn_stats, preds_dict, targets = get_or_run_nn(experiment, filename='027_seq2seq_60to30_000')
# Out:
# keep_prob_rnn_out: 1.0
# lamda2: [1.0, 1e-05, 1.0]
# learning_rate: 0.01
# enc_num_units: 415
# epochs: 10
# dec_num_units: 415
# keep_prob_readout: 1.0
# End Epoch 01 (205.880 secs): err(train) = 0.047429, current dec_ins_percent_usage: 1.00
# cur dtw score: 1.20208429476
# /home/studenthp/anaconda2/envs/dis/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# End Epoch 02 (205.137 secs): err(train) = 0.006829, current dec_ins_percent_usage: 1.00
# cur dtw score: 1.23098010555
# End Epoch 03 (205.133 secs): err(train) = 0.006832, current dec_ins_percent_usage: 1.00
# cur dtw score: 1.27518276615
# End Epoch 04 (205.123 secs): err(train) = 0.006834, current dec_ins_percent_usage: 1.00
# cur dtw score: 1.27421592738
# End Epoch 05 (205.250 secs): err(train) = 0.006832, current dec_ins_percent_usage: 1.00
# cur dtw score: 1.36465841556
# End Epoch 06 (205.272 secs): err(train) = 0.006847, current dec_ins_percent_usage: 1.00
# cur dtw score: 1.26977734095
# End Epoch 07 (205.191 secs): err(train) = 0.006845, current dec_ins_percent_usage: 1.00
# cur dtw score: 1.25072638108
# End Epoch 08 (205.268 secs): err(train) = 0.071554, current dec_ins_percent_usage: 1.00
# cur dtw score: 1.20553766736
# End Epoch 09 (205.191 secs): err(train) = 0.006912, current dec_ins_percent_usage: 1.00
# cur dtw score: 1.24965737416
# End Epoch 10 (205.211 secs): err(train) = 0.006873, current dec_ins_percent_usage: 1.00
# cur dtw score: 1.31737641515
# total test error: 0.00733113649767
# -------------------------------------------------------------
# IOError                     Traceback (most recent call last)
# <ipython-input-27-36082dbd4bfa> in <module>()
#       1 #%%time
# ----> 2 dyn_stats, preds_dict, targets = get_or_run_nn(experiment, filename='027_seq2seq_60to30_000')
#
# /home/studenthp/pligor.george@gmail.com/msc_Artificial_Intelligence/dissertation/04_time_series_prediction/common.pyc in get_or_run_nn(callback, filename, nn_runs_folder)
#      12     else:
#      13         dyn_stats, preds_dict, targets = callback()
# ---> 14         np.savez(filepath, dyn_stats=dyn_stats, preds_dict=preds_dict, targets=targets)
#      15         return dyn_stats, preds_dict, targets
#
# /home/studenthp/anaconda2/envs/dis/lib/python2.7/site-packages/numpy/lib/npyio.pyc in savez(file, *args, **kwds)
#     591
#     592     """
# --> 593     _savez(file, args, kwds, False)
#     594
#     595
#
# /home/studenthp/anaconda2/envs/dis/lib/python2.7/site-packages/numpy/lib/npyio.pyc in _savez(file, args, kwds, compress, allow_pickle, pickle_kwargs)
#     685         compression = zipfile.ZIP_STORED
#     686
# --> 687     zipf = zipfile_factory(file, mode="w", compression=compression)
#     688
#     689     # Stage arrays in a temporary file on disk, before writing to zip.
#
# /home/studenthp/anaconda2/envs/dis/lib/python2.7/site-packages/numpy/lib/npyio.pyc in zipfile_factory(file, *args, **kwargs)
#      99     import zipfile
#     100     kwargs['allowZip64'] = True
# --> 101     return zipfile.ZipFile(file, *args, **kwargs)
#     102
#     103
#
# /home/studenthp/anaconda2/envs/dis/lib/python2.7/zipfile.pyc in __init__(self, file, mode, compression, allowZip64)
#     754             modeDict = {'r' : 'rb', 'w': 'wb', 'a' : 'r+b'}
#     755             try:
# --> 756                 self.fp = open(file, modeDict[mode])
#     757             except IOError:
#     758                 if mode == 'a':
#
# IOError: [Errno 2] No such file or directory: '../data/nn_runs/027_seq2seq_60to30_000.npz'

# %%
dyn_stats.plotStats()
plt.show()

# %%
r2_scores = [r2_score(y_true=targets[ind], y_pred=preds_dict[ind])
            for ind in range(len(targets))]

# %%
ind = np.argmin(r2_scores)
ind

# %%
reals = targets[ind]
preds = preds_dict[ind]

# %%
r2_score(y_true=reals, y_pred=preds)

# %%
#sns.tsplot(data=dp.inputs[ind].flatten())

# %%
fig = plt.figure(figsize=(15,6))
plt.plot(reals, 'b')
plt.plot(preds, 'g')
plt.legend(['reals','preds'])
plt.show()

# %%
# %%time
dtw_scores = [fastdtw(targets[ind], preds_dict[ind])[0]
             for ind in range(len(targets))]

# %%
np.mean(dtw_scores)

# %%
coint(preds, reals)

# %%
cur_ind = np.random.randint(len(targets))
reals = targets[cur_ind]
preds = preds_dict[cur_ind]
fig = plt.figure(figsize=(15,6))
plt.plot(reals, 'b', label='reals')
plt.plot(preds, 'g')
plt.legend(['reals','preds'])
plt.show()

# %% [markdown]
# ### Conclusion
# ???
