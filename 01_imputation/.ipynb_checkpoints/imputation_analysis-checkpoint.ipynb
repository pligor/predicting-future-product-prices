# %%
import numpy as np
import pandas as pd
import csv
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
CSV_FILENAME = "../mobiles_basic_preprocess.csv"

# %%
df = pd.read_csv(CSV_FILENAME, index_col=0, encoding='utf-8', quoting=csv.QUOTE_ALL)
# def crit(xx):
#     print xx
#     return np.isnan(xx)
XX = df.drop(labels=['main_image', 'screen_type', 'display_name', 'future'], axis=1)
#['main_image', 'screen_type', 'display_name', 'sar']
#print df['vertical_resolution'][df['vertical_resolution'] != df['vertical_resolution']].count()
nulls_per_attr_series = XX.isnull().sum()
nulls_per_attr_ratio = nulls_per_attr_series / len(XX)
nulls_per_attr_ratio
# Out:
# cpu_cores                     0.042607
# sim                           0.000000
# wireless_charging             0.046366
# removable_battery             0.013784
# card_slot                     0.007519
# double_back_cam               0.086466
# fast_charge                   0.017544
# flash                         0.026316
# connectivity_bluetooth        0.000000
# connectivity_lightning        0.000000
# connectivity_minijack         0.000000
# connectivity_nfc              0.000000
# connectivity_usb              0.000000
# connectivity_usb_type_c       0.000000
# connectivity_wifi             0.000000
# control_natural_keyboard      0.000000
# control_touchscreen           0.000000
# protection_dust_resistant     0.016291
# protection_rugged             0.016291
# protection_water_resistant    0.016291
# sensor_accelerometer          0.013784
# sensor_altimeter              0.013784
# sensor_barometer              0.013784
# sensor_compass                0.013784
# sensor_fingerprint            0.013784
# sensor_gyroscope              0.013784
# sensor_hall                   0.013784
# sensor_heartbeat_meter        0.013784
# sensor_iris_scanner           0.013784
# sensor_light                  0.013784
#                                 ...
# manufacturer_id_50            0.000000
# manufacturer_id_51            0.000000
# manufacturer_id_52            0.000000
# manufacturer_id_53            0.000000
# manufacturer_id_54            0.000000
# manufacturer_id_55            0.000000
# manufacturer_id_56            0.000000
# manufacturer_id_57            0.000000
# manufacturer_id_58            0.000000
# manufacturer_id_59            0.000000
# manufacturer_id_60            0.000000
# manufacturer_id_61            0.000000
# manufacturer_id_62            0.000000
# manufacturer_id_63            0.000000
# manufacturer_id_64            0.000000
# manufacturer_id_65            0.000000
# manufacturer_id_66            0.000000
# manufacturer_id_67            0.000000
# manufacturer_id_68            0.000000
# manufacturer_id_69            0.000000
# manufacturer_id_70            0.000000
# operating_system_0            0.003759
# operating_system_1            0.003759
# operating_system_2            0.003759
# operating_system_3            0.003759
# height                        0.012531
# width                         0.012531
# depth                         0.012531
# vertical_resolution           0.010025
# horizontal_resolution         0.010025
# Length: 134, dtype: float64

# %%
nulls_per_attr_ratio_positives = nulls_per_attr_ratio[nulls_per_attr_ratio > 0]

# %%
plt.figure(figsize=(17,25))
sns.barplot(nulls_per_attr_ratio_positives.values, nulls_per_attr_ratio_positives.index)
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.show()
